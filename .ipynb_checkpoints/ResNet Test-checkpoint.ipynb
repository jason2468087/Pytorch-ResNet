# %% [markdown]
# # Import Library

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader, Dataset

import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

import matplotlib.pyplot as plt
from PIL import Image
import math
import time
import os
import numpy as np
import natsort
import csv

# %% [markdown]
# # Network Setting

# %%
epochSize = 100
batchSize = 120
testSize = 300
valSize = 120
learningRate = 4e-4
momentum = 0.5
printInterval = 6
outSize = 10

torch.set_default_tensor_type('torch.cuda.FloatTensor')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
torch.cuda.set_device(0)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
# Out:
# Using device: cuda
# GeForce GTX 1050

# %% [markdown]
# # Data Augumentation

# %%
import numbers
inputSize = 224
    
trainAugumentation = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomAffine(20,translate=(0.1,0.1),scale=(0.8,1)),    
    transforms.ToTensor(),
    transforms.Resize((inputSize,inputSize))
])

testAugumentation = transforms.Compose([    
    transforms.ToTensor(),
    transforms.Resize((inputSize,inputSize))
])

# %% [markdown]
# # Data Sets

# %%
dataDir = "C://Users//jason//OneDrive//圖片//Machine Learning Data//CIFAR-10-images-master//"
trainDir = os.path.join(dataDir,'train//')
valDir = os.path.join(dataDir,'val//')
testDir = os.path.join(dataDir,'test//')

trainData = datasets.ImageFolder(trainDir,transform = trainAugumentation)
valData = datasets.ImageFolder(valDir,transform = trainAugumentation)
testData = datasets.ImageFolder(testDir,transform = testAugumentation)

# %% [markdown]
# # Data Loader

# %%
trainLoader = torch.utils.data.DataLoader(trainData,batch_size = batchSize,shuffle = True)
valLoader = torch.utils.data.DataLoader(valData,batch_size = valSize,shuffle = True)
testLoader = torch.utils.data.DataLoader(testData,batch_size = testSize,shuffle = False)

trainDataSize = len(trainLoader.dataset)
valDataSize = len(valLoader.dataset)
testDataSize = len(testLoader.dataset)

# %% [markdown]
# # Check Training Data

# %%
examples = enumerate(testLoader)
batch_idx, (example_data, example_targets) = next(examples)
example_data.shape

fig = plt.figure()
for i in range(9):
    plt.subplot(3,3,i+1)
    #plt.tight_layout()
    plt.imshow(np.transpose(example_data[i], (1, 2, 0)))
    plt.title("Ground Truth: {}".format(example_targets[i]))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# # ResNet 18 Model

# %%
class ResBlock(nn.Module):
    def __init__(self,inChannel,outChannel,isFirstBlock):
        super(ResBlock,self).__init__()
        
        if isFirstBlock:
            strideNum = 1
        else:
            strideNum = 2
        
        self.conv1 = nn.Conv2d(inChannel,outChannel,kernel_size=3,padding=1,stride=strideNum)
        self.bn1 = nn.BatchNorm2d(outChannel)
        self.conv2 = nn.Conv2d(outChannel,outChannel,kernel_size=3,padding=1,stride=1)
        self.bn2 = nn.BatchNorm2d(outChannel)
        
        self.shortcut = nn.Sequential()
        if inChannel != outChannel:
            self.shortcut.add_module('conv',nn.Conv2d(inChannel,outChannel,kernel_size=1,stride=strideNum))
            self.shortcut.add_module('bn',nn.BatchNorm2d(outChannel)) 
        
    def forward(self,x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = F.relu(out)
        
        out = self.conv2(out)
        out = self.bn2(out)
        
        out += self.shortcut(x)
        
        out = F.relu(out)
        
        return out

    
class ResNet(nn.Module):
    def __init__(self):
        super(ResNet,self).__init__()
        
        self.conv1 = nn.Conv2d(3,64,kernel_size=7,padding=3,stride=2)
        self.bn = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(3,stride=2,padding=1)
        
        self.res1 = self._make_resBlock(64,64,'res1',True)
        self.res2 = self._make_resBlock(64,128,'res2',False)
        self.res3 = self._make_resBlock(128,256,'res3',False)
        self.res4 = self._make_resBlock(256,512,'res4',False)
        
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512, 10)
        
    def _make_resBlock(self,inChannel,outChannel,block_name,isFirstBlock):
        resBlock = nn.Sequential()
        resBlock.add_module(block_name, ResBlock(inChannel, outChannel,isFirstBlock))
        
        return resBlock
    
    
    def forward(self,x):
        
        out = self.conv1(x)
        out = F.relu(out)
        out = self.bn(out)
        out = self.pool(out)
        
        out = self.res1(out)        
        out = self.res2(out)        
        out = self.res3(out)        
        out = self.res4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        out = F.log_softmax(out)
        
        return out

# %% [markdown]
# # Create Network

# %%
network = ResNet().cuda()
#network.load_state_dict(torch.load("C:\\Users\\jason\\OneDrive\\文件\\Python NN\\Pytorch Pet\\weights161120.pth"))

optimizer = optim.Adam(network.parameters(), weight_decay=0.01,lr=learningRate)
scheduler = ReduceLROnPlateau(optimizer,verbose=True,patience=8,min_lr=1e-6)

print('Memory Usage:')
print('Allocated:', torch.cuda.memory_allocated(0)/1024/1024, 'MB')
print('Cached:   ', torch.cuda.memory_allocated(0)/1024/1024, 'MB')

pytorch_total_params = sum(p.numel() for p in network.parameters())
print("\nTotal Parameters:",pytorch_total_params)
# Out:
# Memory Usage:
# Allocated: 18.779296875 MB
# Cached:    18.779296875 MB
#
# Total Parameters: 4913802

# %% [markdown]
# # Learning Rate Finder

# %% [markdown]
# def findLearningRate():
#     lr = 1e-7
#
#
#     lossArr = []
#     dLossArr = []
#     d2LossArr = []
#     lrArr = []
#
#     for idx,(data,label) in enumerate(trainLoader):
#
#
#         # Put data to GPU
#         data = data.cuda()
#         label = label.cuda()
#
#         # Computations
#         optimizer.zero_grad()
#         output = network(data)
#         loss = F.nll_loss(output,label)
#         loss.backward()
#         optimizer.step()
#
#         print(lr,loss.item())
#
#         lossArr.append(loss.item())
#         lrArr.append(lr)
#         lr = lr*1.1
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = lr
#
#         if (lr > 0.1):
#             break
#
#     return lossArr,lrArr
#
# lossArr,lrArr = findLearningRate()
# plt.figure(figsize=(15, 9))
# plt.plot(lrArr,lossArr)
# plt.ylabel('some numbers')
# plt.xscale('log')
# plt.show()
#
# def weight_reset(m):
#     if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
#         m.reset_parameters()
#
# network.apply(weight_reset)
#
# for param_group in optimizer.param_groups:
#             param_group['lr'] = 1e-4

# %% [markdown]
# # Result Array

# %%
trainLossArr = []
trainCounterArr = []
valLossArr = []
valCounterArr = []
testLossArr = []
testCounterArr = [(i+1)*len(trainLoader.dataset) for i in range(epochSize)]

# %% [markdown]
# # Training Function

# %%
def train(epoch):
    network.train()
    epoch_loss = 0
    epoch_accuracy = 0
    
    currentImg = 0
    totalImg = len(trainLoader.dataset)
    
    for idx,(data,label) in enumerate(trainLoader):
        # Put data to GPU
        data = data.cuda()
        label = label.cuda()
        
        # Computations
        optimizer.zero_grad()
        output = network(data)
        loss = F.nll_loss(output,label)
        loss.backward()
        optimizer.step()
        
        # Calculate acc and loss
        batch_accuracy = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += (output.argmax(dim=1) == label).float().sum()
        epoch_loss += loss/len(trainLoader)
        
        # Print and record every n interval
        if idx % printInterval == 0:
            
            # Print
            currentImg = idx * len(data)
            epochProgress = currentImg/totalImg
            
            val_accuracy,val_loss = val()
            
            if idx == 0:
                print('Train Epoch: {} [{}/{} (0%)]'.format(epoch,idx, len(trainLoader.dataset)))
            else:                
                print('Train Epoch: {} [{}/{} ({:.0f}%)]  Loss: {:.4f}  Accuracy: {:.4f}  Val_Accuracy: {:.4f}'.format(
                    epoch,currentImg,totalImg,epochProgress*100 ,loss.item(),batch_accuracy,val_accuracy))
            
            # Record
            trainLossArr.append(loss.item())
            trainCounterArr.append(
            (batch_idx*batchSize) + ((epoch-1)*len(trainLoader.dataset)))
            
            valLossArr.append(val_loss)
            valCounterArr.append(
            (batch_idx*batchSize) + ((epoch-1)*len(trainLoader.dataset)))
            
        
    
    # Final print
    print('Train Epoch: {} [{}/{} ({:.0f}%)]  Loss: {:.4f}  Accuracy: {:.4f}  Val_Accuracy: {:.4f}'.format(
                    epoch,totalImg,totalImg,100 ,loss.item(),batch_accuracy,val_accuracy))
    print("Train  Accuracy: {:.4f}  Loss: {:.4f}".format(epoch_accuracy/len(trainLoader.dataset),loss.item()))

# %% [markdown]
# # Testing Function

# %%
def test():
    network.eval()
    test_loss = 0
    test_accuracy = 0
    idx = 0
    with torch.no_grad():
        for data,label in testLoader:
            # Data to GPU and compute
            data = data.to(device)
            label = label.to(device)
            output = network(data)
            test_loss += F.nll_loss(output,label).item()
            #test_accuracy += ((output.argmax(dim=1) == label).float().mean())/len(testLoader)
            test_accuracy += (output.argmax(dim=1) == label).float().sum()
    
    testLossArr.append(test_loss)
    test_accuracy = test_accuracy/len(testLoader.dataset)
    print("Test  Accuracy: {:.4f}  Loss: {:.4f}".format(test_accuracy,test_loss))
    
    return test_loss,test_accuracy

# %% [markdown]
# # Validation Function

# %%
def val():
    #network.eval()
    val_loss = 0
    val_accuracy = 0
    idx = 0
    with torch.no_grad():
        for data,label in valLoader:
            data = data.to(device)
            label = label.to(device)
            output = network(data)
            val_loss += F.nll_loss(output,label).item()
            val_accuracy += ((output.argmax(dim=1) == label).float().mean())/len(valLoader)
            
    network.train()
    
    return val_accuracy,val_loss

# %% [markdown]
# # Change Weight Decay

# %%
def setWeightDecay(acc,wDStage):
    
    acc = acc*100
    if acc> 85 and wDecayStage == 4:
        wDStage = 5
        for param_gp in optimizer.param_groups:
            param_gp['weight_decay'] = 0
            param_gp['lr'] = 2.5e-5
        print('Reduce Weight Decay to ',param_gp['weight_decay'])
    elif acc>80 and wDecayStage == 3:
        wDStage = 4
        for param_gp in optimizer.param_groups:
            param_gp['weight_decay'] = 0.000001
            param_gp['lr'] = 5e-5
        print('Reduce Weight Decay to ',param_gp['weight_decay'])
    elif acc>75 and wDecayStage == 2:
        wDStage = 3
        for param_gp in optimizer.param_groups:
            param_gp['weight_decay'] = 0.00001
            param_gp['lr'] = 1e-4
        print('Reduce Weight Decay to ',param_gp['weight_decay'])
    elif acc>65 and wDecayStage == 1:
        wDStage = 2
        for param_gp in optimizer.param_groups:
            param_gp['weight_decay'] = 0.0001
        print('Reduce Weight Decay to ',param_gp['weight_decay'])
    elif acc>50 and wDecayStage == 0:
        wDStage = 1
        for param_gp in optimizer.param_groups:
            param_gp['weight_decay'] = 0.001
        print('Reduce Weight Decay to ',param_gp['weight_decay'])
    
    return wDStage

# %% [markdown]
# # Start training

# %%
wDecayStage = 0
maxAcc = 0
for epoch in range(1,epochSize+1):
        
    startEpochTime = time.time()
    train(epoch)
    
    loss,acc = test()
    scheduler.step(loss)
    wDecayStage = setWeightDecay(acc,wDecayStage)
    
    
    if acc > maxAcc:
        maxAcc = acc
        torch.save(network.state_dict(), "C:\\Users\\jason\\OneDrive\\文件\\Python NN\\Pytorch ResNet\\weight211120.pth")
        print("Model Saved")
    
    print("Time: {:.4f}".format(time.time()-startEpochTime),end='\n\n')
# Out:
# c:\users\jason\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:73: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 [0/50000 (0%)]
# Train Epoch: 1 [720/50000 (1%)]  Loss: 2.0457  Accuracy: 0.2750  Val_Accuracy: 0.2367
# Train Epoch: 1 [1440/50000 (3%)]  Loss: 1.8997  Accuracy: 0.2833  Val_Accuracy: 0.3183
# Train Epoch: 1 [2160/50000 (4%)]  Loss: 1.7334  Accuracy: 0.3917  Val_Accuracy: 0.3283
# Train Epoch: 1 [2880/50000 (6%)]  Loss: 1.8441  Accuracy: 0.2750  Val_Accuracy: 0.3317
# Train Epoch: 1 [3600/50000 (7%)]  Loss: 1.7187  Accuracy: 0.3583  Val_Accuracy: 0.3267
# Train Epoch: 1 [4320/50000 (9%)]  Loss: 1.6599  Accuracy: 0.3750  Val_Accuracy: 0.3550
# Train Epoch: 1 [5040/50000 (10%)]  Loss: 1.7474  Accuracy: 0.3167  Val_Accuracy: 0.3667
# Train Epoch: 1 [5760/50000 (12%)]  Loss: 1.6801  Accuracy: 0.3583  Val_Accuracy: 0.4417
# Train Epoch: 1 [6480/50000 (13%)]  Loss: 1.8328  Accuracy: 0.3583  Val_Accuracy: 0.3633
# Train Epoch: 1 [7200/50000 (14%)]  Loss: 1.6233  Accuracy: 0.4333  Val_Accuracy: 0.3717
# Train Epoch: 1 [7920/50000 (16%)]  Loss: 1.7269  Accuracy: 0.3833  Val_Accuracy: 0.3700
# Train Epoch: 1 [8640/50000 (17%)]  Loss: 1.5346  Accuracy: 0.4167  Val_Accuracy: 0.3800
# Train Epoch: 1 [9360/50000 (19%)]  Loss: 1.7358  Accuracy: 0.3500  Val_Accuracy: 0.4033
# Train Epoch: 1 [10080/50000 (20%)]  Loss: 1.5813  Accuracy: 0.3917  Val_Accuracy: 0.3817
# Train Epoch: 1 [10800/50000 (22%)]  Loss: 1.6648  Accuracy: 0.3917  Val_Accuracy: 0.4333
# Train Epoch: 1 [11520/50000 (23%)]  Loss: 1.6058  Accuracy: 0.4083  Val_Accuracy: 0.3850
# Train Epoch: 1 [12240/50000 (24%)]  Loss: 1.5308  Accuracy: 0.4167  Val_Accuracy: 0.3950
# Train Epoch: 1 [12960/50000 (26%)]  Loss: 1.5080  Accuracy: 0.4083  Val_Accuracy: 0.4033
# Train Epoch: 1 [13680/50000 (27%)]  Loss: 1.5764  Accuracy: 0.4000  Val_Accuracy: 0.3767
# Train Epoch: 1 [14400/50000 (29%)]  Loss: 1.6566  Accuracy: 0.4167  Val_Accuracy: 0.4000
# Train Epoch: 1 [15120/50000 (30%)]  Loss: 1.5961  Accuracy: 0.4167  Val_Accuracy: 0.4033
# Train Epoch: 1 [15840/50000 (32%)]  Loss: 1.6810  Accuracy: 0.3833  Val_Accuracy: 0.4150
# Train Epoch: 1 [16560/50000 (33%)]  Loss: 1.4827  Accuracy: 0.4250  Val_Accuracy: 0.4283
# Train Epoch: 1 [17280/50000 (35%)]  Loss: 1.4926  Accuracy: 0.4750  Val_Accuracy: 0.3900
# Train Epoch: 1 [18000/50000 (36%)]  Loss: 1.4543  Accuracy: 0.4833  Val_Accuracy: 0.4283
# Train Epoch: 1 [18720/50000 (37%)]  Loss: 1.4908  Accuracy: 0.5083  Val_Accuracy: 0.3833
# Train Epoch: 1 [19440/50000 (39%)]  Loss: 1.4347  Accuracy: 0.4500  Val_Accuracy: 0.4517
# Train Epoch: 1 [20160/50000 (40%)]  Loss: 1.5366  Accuracy: 0.4167  Val_Accuracy: 0.4317
# Train Epoch: 1 [20880/50000 (42%)]  Loss: 1.4451  Accuracy: 0.5000  Val_Accuracy: 0.4017
# Train Epoch: 1 [21600/50000 (43%)]  Loss: 1.4348  Accuracy: 0.4667  Val_Accuracy: 0.4633
# Train Epoch: 1 [22320/50000 (45%)]  Loss: 1.4849  Accuracy: 0.5333  Val_Accuracy: 0.4417
# Train Epoch: 1 [23040/50000 (46%)]  Loss: 1.5552  Accuracy: 0.4417  Val_Accuracy: 0.4583
# Train Epoch: 1 [23760/50000 (48%)]  Loss: 1.4443  Accuracy: 0.4917  Val_Accuracy: 0.4350
# Train Epoch: 1 [24480/50000 (49%)]  Loss: 1.2567  Accuracy: 0.5833  Val_Accuracy: 0.4717
# Train Epoch: 1 [25200/50000 (50%)]  Loss: 1.5267  Accuracy: 0.4083  Val_Accuracy: 0.4600
# Train Epoch: 1 [25920/50000 (52%)]  Loss: 1.3963  Accuracy: 0.5250  Val_Accuracy: 0.4583
# Train Epoch: 1 [26640/50000 (53%)]  Loss: 1.5458  Accuracy: 0.3917  Val_Accuracy: 0.4567
# Train Epoch: 1 [27360/50000 (55%)]  Loss: 1.4115  Accuracy: 0.4333  Val_Accuracy: 0.4167
# Train Epoch: 1 [28080/50000 (56%)]  Loss: 1.5325  Accuracy: 0.4667  Val_Accuracy: 0.4633
# Train Epoch: 1 [28800/50000 (58%)]  Loss: 1.5583  Accuracy: 0.4083  Val_Accuracy: 0.4683
# Train Epoch: 1 [29520/50000 (59%)]  Loss: 1.4338  Accuracy: 0.4667  Val_Accuracy: 0.4667
# Train Epoch: 1 [30240/50000 (60%)]  Loss: 1.4828  Accuracy: 0.4917  Val_Accuracy: 0.4550
# Train Epoch: 1 [30960/50000 (62%)]  Loss: 1.3154  Accuracy: 0.5917  Val_Accuracy: 0.4917
# Train Epoch: 1 [31680/50000 (63%)]  Loss: 1.3527  Accuracy: 0.5167  Val_Accuracy: 0.4650
# Train Epoch: 1 [32400/50000 (65%)]  Loss: 1.4544  Accuracy: 0.4333  Val_Accuracy: 0.4667
# Train Epoch: 1 [33120/50000 (66%)]  Loss: 1.3029  Accuracy: 0.5417  Val_Accuracy: 0.4117
# Train Epoch: 1 [33840/50000 (68%)]  Loss: 1.4600  Accuracy: 0.4333  Val_Accuracy: 0.4750
# Train Epoch: 1 [34560/50000 (69%)]  Loss: 1.3731  Accuracy: 0.5250  Val_Accuracy: 0.5350
# Train Epoch: 1 [35280/50000 (71%)]  Loss: 1.2976  Accuracy: 0.5250  Val_Accuracy: 0.4350
# Train Epoch: 1 [36000/50000 (72%)]  Loss: 1.4321  Accuracy: 0.4833  Val_Accuracy: 0.4750
# Train Epoch: 1 [36720/50000 (73%)]  Loss: 1.2791  Accuracy: 0.5583  Val_Accuracy: 0.4683
# Train Epoch: 1 [37440/50000 (75%)]  Loss: 1.4471  Accuracy: 0.5167  Val_Accuracy: 0.4383
# Train Epoch: 1 [38160/50000 (76%)]  Loss: 1.3609  Accuracy: 0.4500  Val_Accuracy: 0.4333
# Train Epoch: 1 [38880/50000 (78%)]  Loss: 1.4430  Accuracy: 0.4500  Val_Accuracy: 0.4700
# Train Epoch: 1 [39600/50000 (79%)]  Loss: 1.2623  Accuracy: 0.5167  Val_Accuracy: 0.4833
# Train Epoch: 1 [40320/50000 (81%)]  Loss: 1.4478  Accuracy: 0.4833  Val_Accuracy: 0.4483
# Train Epoch: 1 [41040/50000 (82%)]  Loss: 1.2768  Accuracy: 0.5500  Val_Accuracy: 0.4750
# Train Epoch: 1 [41760/50000 (84%)]  Loss: 1.2556  Accuracy: 0.5333  Val_Accuracy: 0.5333
# Train Epoch: 1 [42480/50000 (85%)]  Loss: 1.3233  Accuracy: 0.5583  Val_Accuracy: 0.4900
# Train Epoch: 1 [43200/50000 (86%)]  Loss: 1.4686  Accuracy: 0.4667  Val_Accuracy: 0.4600
# Train Epoch: 1 [43920/50000 (88%)]  Loss: 1.2717  Accuracy: 0.6000  Val_Accuracy: 0.5000
# Train Epoch: 1 [44640/50000 (89%)]  Loss: 1.2818  Accuracy: 0.5167  Val_Accuracy: 0.4633
# Train Epoch: 1 [45360/50000 (91%)]  Loss: 1.3882  Accuracy: 0.4750  Val_Accuracy: 0.4433
# Train Epoch: 1 [46080/50000 (92%)]  Loss: 1.1922  Accuracy: 0.5667  Val_Accuracy: 0.4750
# Train Epoch: 1 [46800/50000 (94%)]  Loss: 1.2551  Accuracy: 0.5583  Val_Accuracy: 0.4517
# Train Epoch: 1 [47520/50000 (95%)]  Loss: 1.4342  Accuracy: 0.4667  Val_Accuracy: 0.5283
# Train Epoch: 1 [48240/50000 (96%)]  Loss: 1.2804  Accuracy: 0.5333  Val_Accuracy: 0.4667
# Train Epoch: 1 [48960/50000 (98%)]  Loss: 1.2240  Accuracy: 0.5583  Val_Accuracy: 0.5067
# Train Epoch: 1 [49680/50000 (99%)]  Loss: 1.3849  Accuracy: 0.4833  Val_Accuracy: 0.5483
# Train Epoch: 1 [50000/50000 (100%)]  Loss: 1.5197  Accuracy: 0.4500  Val_Accuracy: 0.5483
# Train  Accuracy: 0.4494  Loss: 1.5197
# Test  Accuracy: 0.5049  Loss: 47.0223
# Reduce Weight Decay to  0.001
# Model Saved
# Time: 2253.9516
#
# Train Epoch: 2 [0/50000 (0%)]
# Train Epoch: 2 [720/50000 (1%)]  Loss: 1.2553  Accuracy: 0.5833  Val_Accuracy: 0.5083
# Train Epoch: 2 [1440/50000 (3%)]  Loss: 1.2813  Accuracy: 0.5333  Val_Accuracy: 0.5483
# Train Epoch: 2 [2160/50000 (4%)]  Loss: 1.2389  Accuracy: 0.5750  Val_Accuracy: 0.5017
# Train Epoch: 2 [2880/50000 (6%)]  Loss: 1.3481  Accuracy: 0.5500  Val_Accuracy: 0.5667
# Train Epoch: 2 [3600/50000 (7%)]  Loss: 1.3986  Accuracy: 0.5833  Val_Accuracy: 0.5317
# Train Epoch: 2 [4320/50000 (9%)]  Loss: 1.2887  Accuracy: 0.5250  Val_Accuracy: 0.5333
# Train Epoch: 2 [5040/50000 (10%)]  Loss: 1.2220  Accuracy: 0.5500  Val_Accuracy: 0.5217
# Train Epoch: 2 [5760/50000 (12%)]  Loss: 1.2931  Accuracy: 0.5417  Val_Accuracy: 0.4967
# Train Epoch: 2 [6480/50000 (13%)]  Loss: 1.2486  Accuracy: 0.5417  Val_Accuracy: 0.5083
# Train Epoch: 2 [7200/50000 (14%)]  Loss: 1.4044  Accuracy: 0.4833  Val_Accuracy: 0.5417
# Train Epoch: 2 [7920/50000 (16%)]  Loss: 1.1813  Accuracy: 0.5833  Val_Accuracy: 0.5567
# Train Epoch: 2 [8640/50000 (17%)]  Loss: 1.0162  Accuracy: 0.6000  Val_Accuracy: 0.5333
# Train Epoch: 2 [9360/50000 (19%)]  Loss: 1.2349  Accuracy: 0.5833  Val_Accuracy: 0.4683
# Train Epoch: 2 [10080/50000 (20%)]  Loss: 1.1800  Accuracy: 0.5917  Val_Accuracy: 0.5367
# Train Epoch: 2 [10800/50000 (22%)]  Loss: 1.2104  Accuracy: 0.6500  Val_Accuracy: 0.4883
# Train Epoch: 2 [11520/50000 (23%)]  Loss: 1.5101  Accuracy: 0.4250  Val_Accuracy: 0.5317
# Train Epoch: 2 [12240/50000 (24%)]  Loss: 1.0718  Accuracy: 0.6000  Val_Accuracy: 0.5733
# Train Epoch: 2 [12960/50000 (26%)]  Loss: 1.2341  Accuracy: 0.5250  Val_Accuracy: 0.5350
# Train Epoch: 2 [13680/50000 (27%)]  Loss: 1.3616  Accuracy: 0.5083  Val_Accuracy: 0.5483
# Train Epoch: 2 [14400/50000 (29%)]  Loss: 1.3082  Accuracy: 0.5583  Val_Accuracy: 0.5533
# Train Epoch: 2 [15120/50000 (30%)]  Loss: 1.2390  Accuracy: 0.6083  Val_Accuracy: 0.5367
# Train Epoch: 2 [15840/50000 (32%)]  Loss: 1.2122  Accuracy: 0.5750  Val_Accuracy: 0.4800
# Train Epoch: 2 [16560/50000 (33%)]  Loss: 1.2132  Accuracy: 0.5250  Val_Accuracy: 0.5467
# Train Epoch: 2 [17280/50000 (35%)]  Loss: 1.2129  Accuracy: 0.5500  Val_Accuracy: 0.5883
# Train Epoch: 2 [18000/50000 (36%)]  Loss: 1.1402  Accuracy: 0.6000  Val_Accuracy: 0.5833
# Train Epoch: 2 [18720/50000 (37%)]  Loss: 1.2144  Accuracy: 0.5333  Val_Accuracy: 0.5450
# Train Epoch: 2 [19440/50000 (39%)]  Loss: 1.1125  Accuracy: 0.5750  Val_Accuracy: 0.4983
# Train Epoch: 2 [20160/50000 (40%)]  Loss: 1.2313  Accuracy: 0.5667  Val_Accuracy: 0.5167
# Train Epoch: 2 [20880/50000 (42%)]  Loss: 1.1257  Accuracy: 0.5833  Val_Accuracy: 0.5467
# Train Epoch: 2 [21600/50000 (43%)]  Loss: 1.1500  Accuracy: 0.6333  Val_Accuracy: 0.5783
# Train Epoch: 2 [22320/50000 (45%)]  Loss: 1.1311  Accuracy: 0.6167  Val_Accuracy: 0.5100
# Train Epoch: 2 [23040/50000 (46%)]  Loss: 1.1327  Accuracy: 0.6083  Val_Accuracy: 0.5800
# Train Epoch: 2 [23760/50000 (48%)]  Loss: 1.1935  Accuracy: 0.5917  Val_Accuracy: 0.5633
# Train Epoch: 2 [24480/50000 (49%)]  Loss: 1.2848  Accuracy: 0.4833  Val_Accuracy: 0.5700
# Train Epoch: 2 [25200/50000 (50%)]  Loss: 1.1975  Accuracy: 0.5583  Val_Accuracy: 0.5233
# Train Epoch: 2 [25920/50000 (52%)]  Loss: 1.2110  Accuracy: 0.5917  Val_Accuracy: 0.5767
# Train Epoch: 2 [26640/50000 (53%)]  Loss: 1.2345  Accuracy: 0.5750  Val_Accuracy: 0.5800
# Train Epoch: 2 [27360/50000 (55%)]  Loss: 1.1991  Accuracy: 0.6000  Val_Accuracy: 0.5750
# Train Epoch: 2 [28080/50000 (56%)]  Loss: 1.2014  Accuracy: 0.5750  Val_Accuracy: 0.5467
# Train Epoch: 2 [28800/50000 (58%)]  Loss: 1.0618  Accuracy: 0.6583  Val_Accuracy: 0.5567
# Train Epoch: 2 [29520/50000 (59%)]  Loss: 1.2426  Accuracy: 0.5667  Val_Accuracy: 0.5667
# Train Epoch: 2 [30240/50000 (60%)]  Loss: 1.2163  Accuracy: 0.5167  Val_Accuracy: 0.5983
# Train Epoch: 2 [30960/50000 (62%)]  Loss: 1.0399  Accuracy: 0.6667  Val_Accuracy: 0.5733
# Train Epoch: 2 [31680/50000 (63%)]  Loss: 1.1973  Accuracy: 0.5583  Val_Accuracy: 0.6167
# Train Epoch: 2 [32400/50000 (65%)]  Loss: 1.0841  Accuracy: 0.6500  Val_Accuracy: 0.5417
# Train Epoch: 2 [33120/50000 (66%)]  Loss: 1.1103  Accuracy: 0.6083  Val_Accuracy: 0.5783
# Train Epoch: 2 [33840/50000 (68%)]  Loss: 1.1100  Accuracy: 0.5833  Val_Accuracy: 0.5750
# Train Epoch: 2 [34560/50000 (69%)]  Loss: 1.1900  Accuracy: 0.5417  Val_Accuracy: 0.5733
# Train Epoch: 2 [35280/50000 (71%)]  Loss: 1.0595  Accuracy: 0.6167  Val_Accuracy: 0.5433
# Train Epoch: 2 [36000/50000 (72%)]  Loss: 1.1343  Accuracy: 0.6000  Val_Accuracy: 0.5117
# Train Epoch: 2 [36720/50000 (73%)]  Loss: 1.2286  Accuracy: 0.5750  Val_Accuracy: 0.5667
# Train Epoch: 2 [37440/50000 (75%)]  Loss: 1.1810  Accuracy: 0.5250  Val_Accuracy: 0.5750
# Train Epoch: 2 [38160/50000 (76%)]  Loss: 1.2849  Accuracy: 0.5833  Val_Accuracy: 0.5800
# Train Epoch: 2 [38880/50000 (78%)]  Loss: 1.0104  Accuracy: 0.6167  Val_Accuracy: 0.5883
# Train Epoch: 2 [39600/50000 (79%)]  Loss: 1.0177  Accuracy: 0.6417  Val_Accuracy: 0.6117
# Train Epoch: 2 [40320/50000 (81%)]  Loss: 1.0967  Accuracy: 0.6083  Val_Accuracy: 0.5850
# Train Epoch: 2 [41040/50000 (82%)]  Loss: 1.1734  Accuracy: 0.6000  Val_Accuracy: 0.5817
# Train Epoch: 2 [41760/50000 (84%)]  Loss: 1.1200  Accuracy: 0.5917  Val_Accuracy: 0.5517
# Train Epoch: 2 [42480/50000 (85%)]  Loss: 1.0368  Accuracy: 0.6083  Val_Accuracy: 0.5967
# Train Epoch: 2 [43200/50000 (86%)]  Loss: 1.1387  Accuracy: 0.6000  Val_Accuracy: 0.5750
# Train Epoch: 2 [43920/50000 (88%)]  Loss: 1.0522  Accuracy: 0.6667  Val_Accuracy: 0.5600
# Train Epoch: 2 [44640/50000 (89%)]  Loss: 0.9266  Accuracy: 0.6583  Val_Accuracy: 0.5483
# Train Epoch: 2 [45360/50000 (91%)]  Loss: 0.9578  Accuracy: 0.6750  Val_Accuracy: 0.5750
# Train Epoch: 2 [46080/50000 (92%)]  Loss: 1.1332  Accuracy: 0.5750  Val_Accuracy: 0.5683
# Train Epoch: 2 [46800/50000 (94%)]  Loss: 1.0632  Accuracy: 0.6167  Val_Accuracy: 0.5917
# Train Epoch: 2 [47520/50000 (95%)]  Loss: 1.1838  Accuracy: 0.5417  Val_Accuracy: 0.5983
# Train Epoch: 2 [48240/50000 (96%)]  Loss: 1.1076  Accuracy: 0.5667  Val_Accuracy: 0.5967
# Train Epoch: 2 [48960/50000 (98%)]  Loss: 1.0546  Accuracy: 0.5917  Val_Accuracy: 0.6000
# Train Epoch: 2 [49680/50000 (99%)]  Loss: 1.1788  Accuracy: 0.5750  Val_Accuracy: 0.5667
# Train Epoch: 2 [50000/50000 (100%)]  Loss: 1.0547  Accuracy: 0.6375  Val_Accuracy: 0.5667
# Train  Accuracy: 0.5818  Loss: 1.0547
# Test  Accuracy: 0.5718  Loss: 42.9994
# Model Saved
# Time: 900.3017
#
# Train Epoch: 3 [0/50000 (0%)]
# Train Epoch: 3 [720/50000 (1%)]  Loss: 1.1075  Accuracy: 0.6333  Val_Accuracy: 0.5700
# Train Epoch: 3 [1440/50000 (3%)]  Loss: 1.0856  Accuracy: 0.6500  Val_Accuracy: 0.5600
# Train Epoch: 3 [2160/50000 (4%)]  Loss: 1.1197  Accuracy: 0.6083  Val_Accuracy: 0.5950
# Train Epoch: 3 [2880/50000 (6%)]  Loss: 1.1195  Accuracy: 0.6583  Val_Accuracy: 0.6183
# Train Epoch: 3 [3600/50000 (7%)]  Loss: 1.0104  Accuracy: 0.6667  Val_Accuracy: 0.5983
# Train Epoch: 3 [4320/50000 (9%)]  Loss: 0.9382  Accuracy: 0.6833  Val_Accuracy: 0.5750
# Train Epoch: 3 [5040/50000 (10%)]  Loss: 1.0794  Accuracy: 0.5750  Val_Accuracy: 0.5733
# Train Epoch: 3 [5760/50000 (12%)]  Loss: 0.9524  Accuracy: 0.6667  Val_Accuracy: 0.5850
# Train Epoch: 3 [6480/50000 (13%)]  Loss: 1.1183  Accuracy: 0.5750  Val_Accuracy: 0.6100
# Train Epoch: 3 [7200/50000 (14%)]  Loss: 1.1544  Accuracy: 0.6000  Val_Accuracy: 0.5700
# Train Epoch: 3 [7920/50000 (16%)]  Loss: 1.1989  Accuracy: 0.6083  Val_Accuracy: 0.6183
# Train Epoch: 3 [8640/50000 (17%)]  Loss: 0.8877  Accuracy: 0.6917  Val_Accuracy: 0.6167
# Train Epoch: 3 [9360/50000 (19%)]  Loss: 1.0975  Accuracy: 0.5917  Val_Accuracy: 0.5500
# Train Epoch: 3 [10080/50000 (20%)]  Loss: 1.2734  Accuracy: 0.5500  Val_Accuracy: 0.5617
# Train Epoch: 3 [10800/50000 (22%)]  Loss: 1.1530  Accuracy: 0.5917  Val_Accuracy: 0.5933
# Train Epoch: 3 [11520/50000 (23%)]  Loss: 1.0591  Accuracy: 0.5667  Val_Accuracy: 0.6183
# Train Epoch: 3 [12240/50000 (24%)]  Loss: 1.0135  Accuracy: 0.6167  Val_Accuracy: 0.6267
# Train Epoch: 3 [12960/50000 (26%)]  Loss: 1.1711  Accuracy: 0.6083  Val_Accuracy: 0.6150
# Train Epoch: 3 [13680/50000 (27%)]  Loss: 1.2796  Accuracy: 0.5667  Val_Accuracy: 0.5850
# Train Epoch: 3 [14400/50000 (29%)]  Loss: 1.0219  Accuracy: 0.6667  Val_Accuracy: 0.5533
# Train Epoch: 3 [15120/50000 (30%)]  Loss: 1.0808  Accuracy: 0.5917  Val_Accuracy: 0.6067
# Train Epoch: 3 [15840/50000 (32%)]  Loss: 1.0378  Accuracy: 0.6500  Val_Accuracy: 0.5967
# Train Epoch: 3 [16560/50000 (33%)]  Loss: 1.0339  Accuracy: 0.6083  Val_Accuracy: 0.6117
# Train Epoch: 3 [17280/50000 (35%)]  Loss: 1.0611  Accuracy: 0.5833  Val_Accuracy: 0.6433
# Train Epoch: 3 [18000/50000 (36%)]  Loss: 0.9346  Accuracy: 0.6583  Val_Accuracy: 0.6217
# Train Epoch: 3 [18720/50000 (37%)]  Loss: 1.0754  Accuracy: 0.6250  Val_Accuracy: 0.5800
# Train Epoch: 3 [19440/50000 (39%)]  Loss: 0.9324  Accuracy: 0.6917  Val_Accuracy: 0.6117
# Train Epoch: 3 [20160/50000 (40%)]  Loss: 1.1026  Accuracy: 0.6417  Val_Accuracy: 0.6333
# Train Epoch: 3 [20880/50000 (42%)]  Loss: 0.9581  Accuracy: 0.6833  Val_Accuracy: 0.6183
# Train Epoch: 3 [21600/50000 (43%)]  Loss: 1.2504  Accuracy: 0.5750  Val_Accuracy: 0.6083
# Train Epoch: 3 [22320/50000 (45%)]  Loss: 0.8401  Accuracy: 0.7083  Val_Accuracy: 0.5917
# Train Epoch: 3 [23040/50000 (46%)]  Loss: 0.9327  Accuracy: 0.6583  Val_Accuracy: 0.6850
# Train Epoch: 3 [23760/50000 (48%)]  Loss: 1.0136  Accuracy: 0.5833  Val_Accuracy: 0.6283
# Train Epoch: 3 [24480/50000 (49%)]  Loss: 1.0251  Accuracy: 0.6750  Val_Accuracy: 0.5967
# Train Epoch: 3 [25200/50000 (50%)]  Loss: 1.1647  Accuracy: 0.5917  Val_Accuracy: 0.6033
# Train Epoch: 3 [25920/50000 (52%)]  Loss: 1.0933  Accuracy: 0.5583  Val_Accuracy: 0.6517
# Train Epoch: 3 [26640/50000 (53%)]  Loss: 1.0129  Accuracy: 0.6333  Val_Accuracy: 0.6350
# Train Epoch: 3 [27360/50000 (55%)]  Loss: 1.0200  Accuracy: 0.6750  Val_Accuracy: 0.6367
# Train Epoch: 3 [28080/50000 (56%)]  Loss: 0.9301  Accuracy: 0.6500  Val_Accuracy: 0.6333
# Train Epoch: 3 [28800/50000 (58%)]  Loss: 0.9712  Accuracy: 0.6167  Val_Accuracy: 0.6067
# Train Epoch: 3 [29520/50000 (59%)]  Loss: 1.0903  Accuracy: 0.6000  Val_Accuracy: 0.6183
# Train Epoch: 3 [30240/50000 (60%)]  Loss: 1.0862  Accuracy: 0.6167  Val_Accuracy: 0.6267
# Train Epoch: 3 [30960/50000 (62%)]  Loss: 1.0385  Accuracy: 0.6333  Val_Accuracy: 0.5983
# Train Epoch: 3 [31680/50000 (63%)]  Loss: 0.9847  Accuracy: 0.6583  Val_Accuracy: 0.6433
# Train Epoch: 3 [32400/50000 (65%)]  Loss: 0.9241  Accuracy: 0.7000  Val_Accuracy: 0.6750
# Train Epoch: 3 [33120/50000 (66%)]  Loss: 0.9315  Accuracy: 0.6667  Val_Accuracy: 0.6517
# Train Epoch: 3 [33840/50000 (68%)]  Loss: 1.1586  Accuracy: 0.5500  Val_Accuracy: 0.5917
# Train Epoch: 3 [34560/50000 (69%)]  Loss: 0.9569  Accuracy: 0.6833  Val_Accuracy: 0.6367
# Train Epoch: 3 [35280/50000 (71%)]  Loss: 0.9636  Accuracy: 0.6667  Val_Accuracy: 0.6017
# Train Epoch: 3 [36000/50000 (72%)]  Loss: 1.0767  Accuracy: 0.6583  Val_Accuracy: 0.5917
# Train Epoch: 3 [36720/50000 (73%)]  Loss: 1.0644  Accuracy: 0.6417  Val_Accuracy: 0.5717
# Train Epoch: 3 [37440/50000 (75%)]  Loss: 1.2445  Accuracy: 0.5167  Val_Accuracy: 0.6367
# Train Epoch: 3 [38160/50000 (76%)]  Loss: 0.9145  Accuracy: 0.6167  Val_Accuracy: 0.5967
# Train Epoch: 3 [38880/50000 (78%)]  Loss: 1.0139  Accuracy: 0.5917  Val_Accuracy: 0.6350
# Train Epoch: 3 [39600/50000 (79%)]  Loss: 0.9323  Accuracy: 0.6167  Val_Accuracy: 0.5850
# Train Epoch: 3 [40320/50000 (81%)]  Loss: 1.1839  Accuracy: 0.6000  Val_Accuracy: 0.6133
# Train Epoch: 3 [41040/50000 (82%)]  Loss: 1.0198  Accuracy: 0.6583  Val_Accuracy: 0.6433
# Train Epoch: 3 [41760/50000 (84%)]  Loss: 1.1932  Accuracy: 0.5583  Val_Accuracy: 0.5917
# Train Epoch: 3 [42480/50000 (85%)]  Loss: 1.0548  Accuracy: 0.6083  Val_Accuracy: 0.5967
# Train Epoch: 3 [43200/50000 (86%)]  Loss: 1.0656  Accuracy: 0.6083  Val_Accuracy: 0.6617
# Train Epoch: 3 [43920/50000 (88%)]  Loss: 1.0623  Accuracy: 0.6167  Val_Accuracy: 0.5833
# Train Epoch: 3 [44640/50000 (89%)]  Loss: 1.0585  Accuracy: 0.6667  Val_Accuracy: 0.6017
# Train Epoch: 3 [45360/50000 (91%)]  Loss: 1.0685  Accuracy: 0.6500  Val_Accuracy: 0.6333
# Train Epoch: 3 [46080/50000 (92%)]  Loss: 0.9670  Accuracy: 0.6417  Val_Accuracy: 0.6050
# Train Epoch: 3 [46800/50000 (94%)]  Loss: 0.9475  Accuracy: 0.6750  Val_Accuracy: 0.6400
# Train Epoch: 3 [47520/50000 (95%)]  Loss: 1.0748  Accuracy: 0.6250  Val_Accuracy: 0.6100
# Train Epoch: 3 [48240/50000 (96%)]  Loss: 1.1711  Accuracy: 0.5917  Val_Accuracy: 0.6767
# Train Epoch: 3 [48960/50000 (98%)]  Loss: 1.0353  Accuracy: 0.6583  Val_Accuracy: 0.6633
# Train Epoch: 3 [49680/50000 (99%)]  Loss: 1.1314  Accuracy: 0.6083  Val_Accuracy: 0.6067
# Train Epoch: 3 [50000/50000 (100%)]  Loss: 0.9629  Accuracy: 0.6125  Val_Accuracy: 0.6067
# Train  Accuracy: 0.6259  Loss: 0.9629
# Test  Accuracy: 0.6307  Loss: 35.5938
# Model Saved
# Time: 841.7401
#
# Train Epoch: 4 [0/50000 (0%)]
# Train Epoch: 4 [720/50000 (1%)]  Loss: 1.1534  Accuracy: 0.6333  Val_Accuracy: 0.6250
# Train Epoch: 4 [1440/50000 (3%)]  Loss: 1.0550  Accuracy: 0.6167  Val_Accuracy: 0.6267
# Train Epoch: 4 [2160/50000 (4%)]  Loss: 1.0718  Accuracy: 0.5917  Val_Accuracy: 0.6133
# Train Epoch: 4 [2880/50000 (6%)]  Loss: 1.0176  Accuracy: 0.6667  Val_Accuracy: 0.5900
# Train Epoch: 4 [3600/50000 (7%)]  Loss: 0.9811  Accuracy: 0.6250  Val_Accuracy: 0.5517
# Train Epoch: 4 [4320/50000 (9%)]  Loss: 0.7891  Accuracy: 0.7417  Val_Accuracy: 0.5900
# Train Epoch: 4 [5040/50000 (10%)]  Loss: 1.0593  Accuracy: 0.6250  Val_Accuracy: 0.6217
# Train Epoch: 4 [5760/50000 (12%)]  Loss: 0.7673  Accuracy: 0.7500  Val_Accuracy: 0.6150
# Train Epoch: 4 [6480/50000 (13%)]  Loss: 0.9896  Accuracy: 0.6083  Val_Accuracy: 0.6267
# Train Epoch: 4 [7200/50000 (14%)]  Loss: 1.0317  Accuracy: 0.6333  Val_Accuracy: 0.6400
# Train Epoch: 4 [7920/50000 (16%)]  Loss: 0.9765  Accuracy: 0.6750  Val_Accuracy: 0.5950
# Train Epoch: 4 [8640/50000 (17%)]  Loss: 0.8891  Accuracy: 0.6917  Val_Accuracy: 0.6417
# Train Epoch: 4 [9360/50000 (19%)]  Loss: 1.0475  Accuracy: 0.6250  Val_Accuracy: 0.6133
# Train Epoch: 4 [10080/50000 (20%)]  Loss: 0.9576  Accuracy: 0.6833  Val_Accuracy: 0.6417
# Train Epoch: 4 [10800/50000 (22%)]  Loss: 1.0228  Accuracy: 0.5833  Val_Accuracy: 0.6517
# Train Epoch: 4 [11520/50000 (23%)]  Loss: 0.9894  Accuracy: 0.6417  Val_Accuracy: 0.6550
# Train Epoch: 4 [12240/50000 (24%)]  Loss: 1.0642  Accuracy: 0.6250  Val_Accuracy: 0.6267
# Train Epoch: 4 [12960/50000 (26%)]  Loss: 1.1106  Accuracy: 0.6000  Val_Accuracy: 0.5550
# Train Epoch: 4 [13680/50000 (27%)]  Loss: 0.9248  Accuracy: 0.6583  Val_Accuracy: 0.6033
# Train Epoch: 4 [14400/50000 (29%)]  Loss: 0.9513  Accuracy: 0.6750  Val_Accuracy: 0.6367
# Train Epoch: 4 [15120/50000 (30%)]  Loss: 0.9235  Accuracy: 0.7250  Val_Accuracy: 0.6350
# Train Epoch: 4 [15840/50000 (32%)]  Loss: 1.1053  Accuracy: 0.6333  Val_Accuracy: 0.5967
# Train Epoch: 4 [16560/50000 (33%)]  Loss: 0.9745  Accuracy: 0.6667  Val_Accuracy: 0.6200
# Train Epoch: 4 [17280/50000 (35%)]  Loss: 0.8960  Accuracy: 0.6833  Val_Accuracy: 0.6117
# Train Epoch: 4 [18000/50000 (36%)]  Loss: 0.8508  Accuracy: 0.6917  Val_Accuracy: 0.6233
# Train Epoch: 4 [18720/50000 (37%)]  Loss: 0.9917  Accuracy: 0.6167  Val_Accuracy: 0.6733
# Train Epoch: 4 [19440/50000 (39%)]  Loss: 0.8777  Accuracy: 0.7000  Val_Accuracy: 0.6150
# Train Epoch: 4 [20160/50000 (40%)]  Loss: 0.7910  Accuracy: 0.7417  Val_Accuracy: 0.6500
# Train Epoch: 4 [20880/50000 (42%)]  Loss: 0.8635  Accuracy: 0.7250  Val_Accuracy: 0.6267
# Train Epoch: 4 [21600/50000 (43%)]  Loss: 0.9261  Accuracy: 0.7000  Val_Accuracy: 0.5917
# Train Epoch: 4 [22320/50000 (45%)]  Loss: 0.9613  Accuracy: 0.6583  Val_Accuracy: 0.6083
# Train Epoch: 4 [23040/50000 (46%)]  Loss: 0.9647  Accuracy: 0.6333  Val_Accuracy: 0.6417
# Train Epoch: 4 [23760/50000 (48%)]  Loss: 0.8650  Accuracy: 0.7750  Val_Accuracy: 0.6250
# Train Epoch: 4 [24480/50000 (49%)]  Loss: 0.9706  Accuracy: 0.6667  Val_Accuracy: 0.5900
# Train Epoch: 4 [25200/50000 (50%)]  Loss: 0.9853  Accuracy: 0.6583  Val_Accuracy: 0.6300
# Train Epoch: 4 [25920/50000 (52%)]  Loss: 0.9509  Accuracy: 0.6667  Val_Accuracy: 0.5883
# Train Epoch: 4 [26640/50000 (53%)]  Loss: 0.8622  Accuracy: 0.6583  Val_Accuracy: 0.6267
# Train Epoch: 4 [27360/50000 (55%)]  Loss: 1.0176  Accuracy: 0.6500  Val_Accuracy: 0.6117
# Train Epoch: 4 [28080/50000 (56%)]  Loss: 1.0877  Accuracy: 0.6167  Val_Accuracy: 0.6317
# Train Epoch: 4 [28800/50000 (58%)]  Loss: 0.7972  Accuracy: 0.7167  Val_Accuracy: 0.6317
# Train Epoch: 4 [29520/50000 (59%)]  Loss: 0.9247  Accuracy: 0.6750  Val_Accuracy: 0.6133
# Train Epoch: 4 [30240/50000 (60%)]  Loss: 0.8609  Accuracy: 0.7250  Val_Accuracy: 0.6417
# Train Epoch: 4 [30960/50000 (62%)]  Loss: 0.9323  Accuracy: 0.6167  Val_Accuracy: 0.6100
# Train Epoch: 4 [31680/50000 (63%)]  Loss: 0.9767  Accuracy: 0.6333  Val_Accuracy: 0.6500
# Train Epoch: 4 [32400/50000 (65%)]  Loss: 0.9724  Accuracy: 0.6667  Val_Accuracy: 0.6733
# Train Epoch: 4 [33120/50000 (66%)]  Loss: 0.8426  Accuracy: 0.7167  Val_Accuracy: 0.6500
# Train Epoch: 4 [33840/50000 (68%)]  Loss: 0.9989  Accuracy: 0.6583  Val_Accuracy: 0.6367
# Train Epoch: 4 [34560/50000 (69%)]  Loss: 0.8618  Accuracy: 0.7083  Val_Accuracy: 0.6033
# Train Epoch: 4 [35280/50000 (71%)]  Loss: 0.8486  Accuracy: 0.6833  Val_Accuracy: 0.5983
# Train Epoch: 4 [36000/50000 (72%)]  Loss: 1.0012  Accuracy: 0.7167  Val_Accuracy: 0.6550
# Train Epoch: 4 [36720/50000 (73%)]  Loss: 0.8434  Accuracy: 0.6417  Val_Accuracy: 0.6150
# Train Epoch: 4 [37440/50000 (75%)]  Loss: 1.0373  Accuracy: 0.6167  Val_Accuracy: 0.6250
# Train Epoch: 4 [38160/50000 (76%)]  Loss: 1.1004  Accuracy: 0.6083  Val_Accuracy: 0.6267
# Train Epoch: 4 [38880/50000 (78%)]  Loss: 0.9974  Accuracy: 0.6417  Val_Accuracy: 0.6483
# Train Epoch: 4 [39600/50000 (79%)]  Loss: 0.9915  Accuracy: 0.6167  Val_Accuracy: 0.6483
# Train Epoch: 4 [40320/50000 (81%)]  Loss: 0.9308  Accuracy: 0.6417  Val_Accuracy: 0.6567
# Train Epoch: 4 [41040/50000 (82%)]  Loss: 1.0045  Accuracy: 0.6750  Val_Accuracy: 0.6400
# Train Epoch: 4 [41760/50000 (84%)]  Loss: 0.9184  Accuracy: 0.6750  Val_Accuracy: 0.6800
# Train Epoch: 4 [42480/50000 (85%)]  Loss: 0.9575  Accuracy: 0.6667  Val_Accuracy: 0.6700
# Train Epoch: 4 [43200/50000 (86%)]  Loss: 1.0206  Accuracy: 0.6667  Val_Accuracy: 0.6483
# Train Epoch: 4 [43920/50000 (88%)]  Loss: 0.9179  Accuracy: 0.7000  Val_Accuracy: 0.6367
# Train Epoch: 4 [44640/50000 (89%)]  Loss: 0.9700  Accuracy: 0.6500  Val_Accuracy: 0.6467
# Train Epoch: 4 [45360/50000 (91%)]  Loss: 0.8863  Accuracy: 0.7333  Val_Accuracy: 0.6367
# Train Epoch: 4 [46080/50000 (92%)]  Loss: 0.9620  Accuracy: 0.6333  Val_Accuracy: 0.6750
# Train Epoch: 4 [46800/50000 (94%)]  Loss: 0.8447  Accuracy: 0.7167  Val_Accuracy: 0.6433
# Train Epoch: 4 [47520/50000 (95%)]  Loss: 0.8553  Accuracy: 0.7000  Val_Accuracy: 0.6633
# Train Epoch: 4 [48240/50000 (96%)]  Loss: 0.8636  Accuracy: 0.6833  Val_Accuracy: 0.6617
# Train Epoch: 4 [48960/50000 (98%)]  Loss: 0.8422  Accuracy: 0.6833  Val_Accuracy: 0.6483
# Train Epoch: 4 [49680/50000 (99%)]  Loss: 0.7830  Accuracy: 0.7250  Val_Accuracy: 0.6100
# Train Epoch: 4 [50000/50000 (100%)]  Loss: 0.7765  Accuracy: 0.7625  Val_Accuracy: 0.6100
# Train  Accuracy: 0.6605  Loss: 0.7765
# Test  Accuracy: 0.6163  Loss: 37.1235
# Time: 937.5793
#
# Train Epoch: 5 [0/50000 (0%)]
# Train Epoch: 5 [720/50000 (1%)]  Loss: 0.9461  Accuracy: 0.6333  Val_Accuracy: 0.6683
# Train Epoch: 5 [1440/50000 (3%)]  Loss: 0.8971  Accuracy: 0.7083  Val_Accuracy: 0.6633
# Train Epoch: 5 [2160/50000 (4%)]  Loss: 0.8746  Accuracy: 0.6667  Val_Accuracy: 0.6433
# Train Epoch: 5 [2880/50000 (6%)]  Loss: 0.8225  Accuracy: 0.6917  Val_Accuracy: 0.6850
# Train Epoch: 5 [3600/50000 (7%)]  Loss: 0.9257  Accuracy: 0.7000  Val_Accuracy: 0.6633
# Train Epoch: 5 [4320/50000 (9%)]  Loss: 1.0499  Accuracy: 0.6583  Val_Accuracy: 0.6600
# Train Epoch: 5 [5040/50000 (10%)]  Loss: 0.8753  Accuracy: 0.6583  Val_Accuracy: 0.6050
# Train Epoch: 5 [5760/50000 (12%)]  Loss: 0.9279  Accuracy: 0.6833  Val_Accuracy: 0.6300
# Train Epoch: 5 [6480/50000 (13%)]  Loss: 0.8570  Accuracy: 0.7000  Val_Accuracy: 0.6700
# Train Epoch: 5 [7200/50000 (14%)]  Loss: 0.9068  Accuracy: 0.6750  Val_Accuracy: 0.6800
# Train Epoch: 5 [7920/50000 (16%)]  Loss: 0.9713  Accuracy: 0.6250  Val_Accuracy: 0.6767
# Train Epoch: 5 [8640/50000 (17%)]  Loss: 1.0064  Accuracy: 0.6000  Val_Accuracy: 0.6500
# Train Epoch: 5 [9360/50000 (19%)]  Loss: 1.0492  Accuracy: 0.6333  Val_Accuracy: 0.6817
# Train Epoch: 5 [10080/50000 (20%)]  Loss: 0.7483  Accuracy: 0.7417  Val_Accuracy: 0.6300
# Train Epoch: 5 [10800/50000 (22%)]  Loss: 0.9489  Accuracy: 0.6417  Val_Accuracy: 0.6800
# Train Epoch: 5 [11520/50000 (23%)]  Loss: 0.9310  Accuracy: 0.6833  Val_Accuracy: 0.6567
# Train Epoch: 5 [12240/50000 (24%)]  Loss: 1.0901  Accuracy: 0.6500  Val_Accuracy: 0.6100
# Train Epoch: 5 [12960/50000 (26%)]  Loss: 0.7965  Accuracy: 0.7167  Val_Accuracy: 0.6750
# Train Epoch: 5 [13680/50000 (27%)]  Loss: 0.9459  Accuracy: 0.6500  Val_Accuracy: 0.6250
# Train Epoch: 5 [14400/50000 (29%)]  Loss: 0.9339  Accuracy: 0.6417  Val_Accuracy: 0.6550
# Train Epoch: 5 [15120/50000 (30%)]  Loss: 0.8767  Accuracy: 0.6917  Val_Accuracy: 0.6667
# Train Epoch: 5 [15840/50000 (32%)]  Loss: 0.7788  Accuracy: 0.7250  Val_Accuracy: 0.6633
# Train Epoch: 5 [16560/50000 (33%)]  Loss: 0.9511  Accuracy: 0.6917  Val_Accuracy: 0.6367
# Train Epoch: 5 [17280/50000 (35%)]  Loss: 0.8507  Accuracy: 0.7167  Val_Accuracy: 0.6283
# Train Epoch: 5 [18000/50000 (36%)]  Loss: 0.8510  Accuracy: 0.7000  Val_Accuracy: 0.6800
# Train Epoch: 5 [18720/50000 (37%)]  Loss: 0.9479  Accuracy: 0.6750  Val_Accuracy: 0.6867
# Train Epoch: 5 [19440/50000 (39%)]  Loss: 0.8003  Accuracy: 0.7000  Val_Accuracy: 0.6583
# Train Epoch: 5 [20160/50000 (40%)]  Loss: 0.9592  Accuracy: 0.6500  Val_Accuracy: 0.6850
# Train Epoch: 5 [20880/50000 (42%)]  Loss: 0.7907  Accuracy: 0.7500  Val_Accuracy: 0.6900
# Train Epoch: 5 [21600/50000 (43%)]  Loss: 0.9105  Accuracy: 0.7083  Val_Accuracy: 0.6350
# Train Epoch: 5 [22320/50000 (45%)]  Loss: 0.8033  Accuracy: 0.7250  Val_Accuracy: 0.6850
# Train Epoch: 5 [23040/50000 (46%)]  Loss: 0.8418  Accuracy: 0.7083  Val_Accuracy: 0.6583
# Train Epoch: 5 [23760/50000 (48%)]  Loss: 1.0512  Accuracy: 0.6417  Val_Accuracy: 0.6067
# Train Epoch: 5 [24480/50000 (49%)]  Loss: 0.7258  Accuracy: 0.7250  Val_Accuracy: 0.6783
# Train Epoch: 5 [25200/50000 (50%)]  Loss: 1.0024  Accuracy: 0.6583  Val_Accuracy: 0.6450
# Train Epoch: 5 [25920/50000 (52%)]  Loss: 0.8513  Accuracy: 0.7333  Val_Accuracy: 0.6633
# Train Epoch: 5 [26640/50000 (53%)]  Loss: 0.7852  Accuracy: 0.7250  Val_Accuracy: 0.7000
# Train Epoch: 5 [27360/50000 (55%)]  Loss: 0.8977  Accuracy: 0.6833  Val_Accuracy: 0.6333
# Train Epoch: 5 [28080/50000 (56%)]  Loss: 0.7236  Accuracy: 0.7250  Val_Accuracy: 0.6183
# Train Epoch: 5 [28800/50000 (58%)]  Loss: 0.7852  Accuracy: 0.7083  Val_Accuracy: 0.6750
# Train Epoch: 5 [29520/50000 (59%)]  Loss: 0.7646  Accuracy: 0.7417  Val_Accuracy: 0.6767
# Train Epoch: 5 [30240/50000 (60%)]  Loss: 1.1231  Accuracy: 0.6000  Val_Accuracy: 0.6300
# Train Epoch: 5 [30960/50000 (62%)]  Loss: 0.8870  Accuracy: 0.7000  Val_Accuracy: 0.6567
# Train Epoch: 5 [31680/50000 (63%)]  Loss: 1.0003  Accuracy: 0.6167  Val_Accuracy: 0.6550
# Train Epoch: 5 [32400/50000 (65%)]  Loss: 0.9364  Accuracy: 0.6583  Val_Accuracy: 0.6567
# Train Epoch: 5 [33120/50000 (66%)]  Loss: 1.0084  Accuracy: 0.6167  Val_Accuracy: 0.6617
# Train Epoch: 5 [33840/50000 (68%)]  Loss: 1.0182  Accuracy: 0.6917  Val_Accuracy: 0.6483
# Train Epoch: 5 [34560/50000 (69%)]  Loss: 0.9761  Accuracy: 0.6917  Val_Accuracy: 0.6333
# Train Epoch: 5 [35280/50000 (71%)]  Loss: 0.7640  Accuracy: 0.7667  Val_Accuracy: 0.7017
# Train Epoch: 5 [36000/50000 (72%)]  Loss: 0.8072  Accuracy: 0.7000  Val_Accuracy: 0.6500
# Train Epoch: 5 [36720/50000 (73%)]  Loss: 0.9254  Accuracy: 0.6167  Val_Accuracy: 0.7100
# Train Epoch: 5 [37440/50000 (75%)]  Loss: 0.8276  Accuracy: 0.6917  Val_Accuracy: 0.6533
# Train Epoch: 5 [38160/50000 (76%)]  Loss: 0.8198  Accuracy: 0.7750  Val_Accuracy: 0.6667
# Train Epoch: 5 [38880/50000 (78%)]  Loss: 0.9594  Accuracy: 0.6500  Val_Accuracy: 0.7133
# Train Epoch: 5 [39600/50000 (79%)]  Loss: 0.7762  Accuracy: 0.7000  Val_Accuracy: 0.6633
# Train Epoch: 5 [40320/50000 (81%)]  Loss: 0.7915  Accuracy: 0.7417  Val_Accuracy: 0.6533
# Train Epoch: 5 [41040/50000 (82%)]  Loss: 0.9715  Accuracy: 0.6500  Val_Accuracy: 0.6317
# Train Epoch: 5 [41760/50000 (84%)]  Loss: 0.9982  Accuracy: 0.6333  Val_Accuracy: 0.6100
# Train Epoch: 5 [42480/50000 (85%)]  Loss: 0.8779  Accuracy: 0.6750  Val_Accuracy: 0.6717
# Train Epoch: 5 [43200/50000 (86%)]  Loss: 0.7417  Accuracy: 0.7750  Val_Accuracy: 0.6200
# Train Epoch: 5 [43920/50000 (88%)]  Loss: 0.9653  Accuracy: 0.6583  Val_Accuracy: 0.6350
# Train Epoch: 5 [44640/50000 (89%)]  Loss: 0.8099  Accuracy: 0.7250  Val_Accuracy: 0.7117
# Train Epoch: 5 [45360/50000 (91%)]  Loss: 0.8093  Accuracy: 0.6917  Val_Accuracy: 0.7383
# Train Epoch: 5 [46080/50000 (92%)]  Loss: 1.0414  Accuracy: 0.6583  Val_Accuracy: 0.7133
# Train Epoch: 5 [46800/50000 (94%)]  Loss: 0.9316  Accuracy: 0.6667  Val_Accuracy: 0.6800
# Train Epoch: 5 [47520/50000 (95%)]  Loss: 0.8487  Accuracy: 0.6583  Val_Accuracy: 0.6567
# Train Epoch: 5 [48240/50000 (96%)]  Loss: 0.7527  Accuracy: 0.7417  Val_Accuracy: 0.6683
# Train Epoch: 5 [48960/50000 (98%)]  Loss: 0.9665  Accuracy: 0.6500  Val_Accuracy: 0.6967
# Train Epoch: 5 [49680/50000 (99%)]  Loss: 0.9533  Accuracy: 0.7000  Val_Accuracy: 0.6783
# Train Epoch: 5 [50000/50000 (100%)]  Loss: 0.7695  Accuracy: 0.7500  Val_Accuracy: 0.6783
# Train  Accuracy: 0.6835  Loss: 0.7695
# Test  Accuracy: 0.6574  Loss: 32.8207
# Reduce Weight Decay to  0.0001
# Model Saved
# Time: 836.7341
#
# Train Epoch: 6 [0/50000 (0%)]
# Train Epoch: 6 [720/50000 (1%)]  Loss: 0.7779  Accuracy: 0.6750  Val_Accuracy: 0.6733
# Train Epoch: 6 [1440/50000 (3%)]  Loss: 0.8702  Accuracy: 0.6583  Val_Accuracy: 0.6783
# Train Epoch: 6 [2160/50000 (4%)]  Loss: 0.8632  Accuracy: 0.6833  Val_Accuracy: 0.6683
# Train Epoch: 6 [2880/50000 (6%)]  Loss: 0.9045  Accuracy: 0.6417  Val_Accuracy: 0.6883
# Train Epoch: 6 [3600/50000 (7%)]  Loss: 0.8089  Accuracy: 0.6917  Val_Accuracy: 0.6767
# Train Epoch: 6 [4320/50000 (9%)]  Loss: 0.7986  Accuracy: 0.7250  Val_Accuracy: 0.6517
# Train Epoch: 6 [5040/50000 (10%)]  Loss: 0.8629  Accuracy: 0.7250  Val_Accuracy: 0.6933
# Train Epoch: 6 [5760/50000 (12%)]  Loss: 0.6957  Accuracy: 0.7667  Val_Accuracy: 0.6517
# Train Epoch: 6 [6480/50000 (13%)]  Loss: 1.0108  Accuracy: 0.6500  Val_Accuracy: 0.6833
# Train Epoch: 6 [7200/50000 (14%)]  Loss: 0.7071  Accuracy: 0.7417  Val_Accuracy: 0.6767
# Train Epoch: 6 [7920/50000 (16%)]  Loss: 0.6724  Accuracy: 0.7917  Val_Accuracy: 0.6750
# Train Epoch: 6 [8640/50000 (17%)]  Loss: 1.1285  Accuracy: 0.5833  Val_Accuracy: 0.6467
# Train Epoch: 6 [9360/50000 (19%)]  Loss: 1.0367  Accuracy: 0.6250  Val_Accuracy: 0.7133
# Train Epoch: 6 [10080/50000 (20%)]  Loss: 0.8645  Accuracy: 0.6833  Val_Accuracy: 0.7017
# Train Epoch: 6 [10800/50000 (22%)]  Loss: 0.8813  Accuracy: 0.6583  Val_Accuracy: 0.7017
# Train Epoch: 6 [11520/50000 (23%)]  Loss: 0.8509  Accuracy: 0.7083  Val_Accuracy: 0.7450
# Train Epoch: 6 [12240/50000 (24%)]  Loss: 0.8487  Accuracy: 0.7333  Val_Accuracy: 0.6967
# Train Epoch: 6 [12960/50000 (26%)]  Loss: 0.8133  Accuracy: 0.7250  Val_Accuracy: 0.6567
# Train Epoch: 6 [13680/50000 (27%)]  Loss: 0.7655  Accuracy: 0.7417  Val_Accuracy: 0.7267
# Train Epoch: 6 [14400/50000 (29%)]  Loss: 0.7860  Accuracy: 0.7167  Val_Accuracy: 0.6933
# Train Epoch: 6 [15120/50000 (30%)]  Loss: 0.8175  Accuracy: 0.7417  Val_Accuracy: 0.6667
# Train Epoch: 6 [15840/50000 (32%)]  Loss: 0.6766  Accuracy: 0.7833  Val_Accuracy: 0.6900
# Train Epoch: 6 [16560/50000 (33%)]  Loss: 0.9849  Accuracy: 0.6500  Val_Accuracy: 0.7133
# Train Epoch: 6 [17280/50000 (35%)]  Loss: 0.6742  Accuracy: 0.7917  Val_Accuracy: 0.7067
# Train Epoch: 6 [18000/50000 (36%)]  Loss: 0.8596  Accuracy: 0.7000  Val_Accuracy: 0.7467
# Train Epoch: 6 [18720/50000 (37%)]  Loss: 0.7631  Accuracy: 0.7750  Val_Accuracy: 0.7050
# Train Epoch: 6 [19440/50000 (39%)]  Loss: 0.8051  Accuracy: 0.7333  Val_Accuracy: 0.6883
# Train Epoch: 6 [20160/50000 (40%)]  Loss: 0.7849  Accuracy: 0.7250  Val_Accuracy: 0.6767
# Train Epoch: 6 [20880/50000 (42%)]  Loss: 0.8561  Accuracy: 0.7000  Val_Accuracy: 0.7033
# Train Epoch: 6 [21600/50000 (43%)]  Loss: 0.8611  Accuracy: 0.6583  Val_Accuracy: 0.7000
# Train Epoch: 6 [22320/50000 (45%)]  Loss: 0.7404  Accuracy: 0.7500  Val_Accuracy: 0.7100
# Train Epoch: 6 [23040/50000 (46%)]  Loss: 0.8019  Accuracy: 0.7083  Val_Accuracy: 0.6917
# Train Epoch: 6 [23760/50000 (48%)]  Loss: 0.7691  Accuracy: 0.7333  Val_Accuracy: 0.7100
# Train Epoch: 6 [24480/50000 (49%)]  Loss: 0.7380  Accuracy: 0.7417  Val_Accuracy: 0.7117
# Train Epoch: 6 [25200/50000 (50%)]  Loss: 0.8677  Accuracy: 0.6833  Val_Accuracy: 0.6733
# Train Epoch: 6 [25920/50000 (52%)]  Loss: 0.8241  Accuracy: 0.7083  Val_Accuracy: 0.6683
# Train Epoch: 6 [26640/50000 (53%)]  Loss: 0.8993  Accuracy: 0.6667  Val_Accuracy: 0.7000
# Train Epoch: 6 [27360/50000 (55%)]  Loss: 0.7801  Accuracy: 0.7167  Val_Accuracy: 0.6633
# Train Epoch: 6 [28080/50000 (56%)]  Loss: 0.7249  Accuracy: 0.7750  Val_Accuracy: 0.7200
# Train Epoch: 6 [28800/50000 (58%)]  Loss: 0.8676  Accuracy: 0.6750  Val_Accuracy: 0.7100
# Train Epoch: 6 [29520/50000 (59%)]  Loss: 0.7507  Accuracy: 0.6917  Val_Accuracy: 0.6617
# Train Epoch: 6 [30240/50000 (60%)]  Loss: 0.6845  Accuracy: 0.7167  Val_Accuracy: 0.7117
# Train Epoch: 6 [30960/50000 (62%)]  Loss: 0.9643  Accuracy: 0.6750  Val_Accuracy: 0.7200
# Train Epoch: 6 [31680/50000 (63%)]  Loss: 0.8828  Accuracy: 0.7000  Val_Accuracy: 0.7100
# Train Epoch: 6 [32400/50000 (65%)]  Loss: 0.7280  Accuracy: 0.7583  Val_Accuracy: 0.7117
# Train Epoch: 6 [33120/50000 (66%)]  Loss: 0.7776  Accuracy: 0.7083  Val_Accuracy: 0.6900
# Train Epoch: 6 [33840/50000 (68%)]  Loss: 0.8855  Accuracy: 0.6667  Val_Accuracy: 0.6783
# Train Epoch: 6 [34560/50000 (69%)]  Loss: 0.9042  Accuracy: 0.6833  Val_Accuracy: 0.7167
# Train Epoch: 6 [35280/50000 (71%)]  Loss: 1.1258  Accuracy: 0.5917  Val_Accuracy: 0.6567
# Train Epoch: 6 [36000/50000 (72%)]  Loss: 0.7987  Accuracy: 0.7250  Val_Accuracy: 0.7333
# Train Epoch: 6 [36720/50000 (73%)]  Loss: 0.8994  Accuracy: 0.7083  Val_Accuracy: 0.7300
# Train Epoch: 6 [37440/50000 (75%)]  Loss: 0.7454  Accuracy: 0.7083  Val_Accuracy: 0.7400
# Train Epoch: 6 [38160/50000 (76%)]  Loss: 0.9538  Accuracy: 0.6333  Val_Accuracy: 0.6967
# Train Epoch: 6 [38880/50000 (78%)]  Loss: 0.8947  Accuracy: 0.6833  Val_Accuracy: 0.6750
# Train Epoch: 6 [39600/50000 (79%)]  Loss: 0.7037  Accuracy: 0.7417  Val_Accuracy: 0.6883
# Train Epoch: 6 [40320/50000 (81%)]  Loss: 0.9160  Accuracy: 0.6833  Val_Accuracy: 0.6817
# Train Epoch: 6 [41040/50000 (82%)]  Loss: 0.7855  Accuracy: 0.7250  Val_Accuracy: 0.7150
# Train Epoch: 6 [41760/50000 (84%)]  Loss: 0.7438  Accuracy: 0.7417  Val_Accuracy: 0.7333
# Train Epoch: 6 [42480/50000 (85%)]  Loss: 0.7580  Accuracy: 0.7583  Val_Accuracy: 0.7183
# Train Epoch: 6 [43200/50000 (86%)]  Loss: 0.7882  Accuracy: 0.7333  Val_Accuracy: 0.6950
# Train Epoch: 6 [43920/50000 (88%)]  Loss: 0.7542  Accuracy: 0.7500  Val_Accuracy: 0.6850
# Train Epoch: 6 [44640/50000 (89%)]  Loss: 0.8110  Accuracy: 0.7167  Val_Accuracy: 0.6967
# Train Epoch: 6 [45360/50000 (91%)]  Loss: 0.7084  Accuracy: 0.7917  Val_Accuracy: 0.6850
# Train Epoch: 6 [46080/50000 (92%)]  Loss: 0.7846  Accuracy: 0.6750  Val_Accuracy: 0.7267
# Train Epoch: 6 [46800/50000 (94%)]  Loss: 0.9519  Accuracy: 0.6917  Val_Accuracy: 0.6833
# Train Epoch: 6 [47520/50000 (95%)]  Loss: 0.8226  Accuracy: 0.7000  Val_Accuracy: 0.7067
# Train Epoch: 6 [48240/50000 (96%)]  Loss: 0.7691  Accuracy: 0.7250  Val_Accuracy: 0.6883
# Train Epoch: 6 [48960/50000 (98%)]  Loss: 0.7161  Accuracy: 0.7417  Val_Accuracy: 0.7450
# Train Epoch: 6 [49680/50000 (99%)]  Loss: 0.9380  Accuracy: 0.6500  Val_Accuracy: 0.6833
# Train Epoch: 6 [50000/50000 (100%)]  Loss: 0.9413  Accuracy: 0.6375  Val_Accuracy: 0.6833
# Train  Accuracy: 0.7117  Loss: 0.9413
# Test  Accuracy: 0.6836  Loss: 31.9302
# Model Saved
# Time: 798.2021
#
# Train Epoch: 7 [0/50000 (0%)]
# Train Epoch: 7 [720/50000 (1%)]  Loss: 0.8605  Accuracy: 0.7250  Val_Accuracy: 0.7383
# Train Epoch: 7 [1440/50000 (3%)]  Loss: 0.8801  Accuracy: 0.7167  Val_Accuracy: 0.7033
# Train Epoch: 7 [2160/50000 (4%)]  Loss: 0.8370  Accuracy: 0.7000  Val_Accuracy: 0.7133
# Train Epoch: 7 [2880/50000 (6%)]  Loss: 0.7554  Accuracy: 0.7417  Val_Accuracy: 0.6850
# Train Epoch: 7 [3600/50000 (7%)]  Loss: 0.7397  Accuracy: 0.7417  Val_Accuracy: 0.7483
# Train Epoch: 7 [4320/50000 (9%)]  Loss: 0.9190  Accuracy: 0.7000  Val_Accuracy: 0.7400
# Train Epoch: 7 [5040/50000 (10%)]  Loss: 0.7397  Accuracy: 0.7167  Val_Accuracy: 0.7417
# Train Epoch: 7 [5760/50000 (12%)]  Loss: 0.6237  Accuracy: 0.7667  Val_Accuracy: 0.7217
# Train Epoch: 7 [6480/50000 (13%)]  Loss: 0.5121  Accuracy: 0.8250  Val_Accuracy: 0.6667
# Train Epoch: 7 [7200/50000 (14%)]  Loss: 0.6403  Accuracy: 0.7750  Val_Accuracy: 0.7067
# Train Epoch: 7 [7920/50000 (16%)]  Loss: 0.9064  Accuracy: 0.7000  Val_Accuracy: 0.6833
# Train Epoch: 7 [8640/50000 (17%)]  Loss: 0.6923  Accuracy: 0.8167  Val_Accuracy: 0.7283
# Train Epoch: 7 [9360/50000 (19%)]  Loss: 0.9123  Accuracy: 0.7000  Val_Accuracy: 0.6867
# Train Epoch: 7 [10080/50000 (20%)]  Loss: 0.7568  Accuracy: 0.7250  Val_Accuracy: 0.7083
# Train Epoch: 7 [10800/50000 (22%)]  Loss: 0.7287  Accuracy: 0.7500  Val_Accuracy: 0.7033
# Train Epoch: 7 [11520/50000 (23%)]  Loss: 0.8852  Accuracy: 0.7000  Val_Accuracy: 0.7267
# Train Epoch: 7 [12240/50000 (24%)]  Loss: 0.8146  Accuracy: 0.7250  Val_Accuracy: 0.7417
# Train Epoch: 7 [12960/50000 (26%)]  Loss: 0.8143  Accuracy: 0.7000  Val_Accuracy: 0.7033
# Train Epoch: 7 [13680/50000 (27%)]  Loss: 0.6761  Accuracy: 0.7833  Val_Accuracy: 0.7017
# Train Epoch: 7 [14400/50000 (29%)]  Loss: 0.8726  Accuracy: 0.6917  Val_Accuracy: 0.7167
# Train Epoch: 7 [15120/50000 (30%)]  Loss: 0.9026  Accuracy: 0.7000  Val_Accuracy: 0.6983
# Train Epoch: 7 [15840/50000 (32%)]  Loss: 0.6049  Accuracy: 0.8250  Val_Accuracy: 0.7150
# Train Epoch: 7 [16560/50000 (33%)]  Loss: 0.8131  Accuracy: 0.7083  Val_Accuracy: 0.6417
# Train Epoch: 7 [17280/50000 (35%)]  Loss: 0.7052  Accuracy: 0.7667  Val_Accuracy: 0.7217
# Train Epoch: 7 [18000/50000 (36%)]  Loss: 0.7759  Accuracy: 0.7333  Val_Accuracy: 0.7133
# Train Epoch: 7 [18720/50000 (37%)]  Loss: 0.6278  Accuracy: 0.7750  Val_Accuracy: 0.7033
# Train Epoch: 7 [19440/50000 (39%)]  Loss: 0.8550  Accuracy: 0.6750  Val_Accuracy: 0.7083
# Train Epoch: 7 [20160/50000 (40%)]  Loss: 0.7173  Accuracy: 0.7667  Val_Accuracy: 0.6983
# Train Epoch: 7 [20880/50000 (42%)]  Loss: 0.7008  Accuracy: 0.7500  Val_Accuracy: 0.7683
# Train Epoch: 7 [21600/50000 (43%)]  Loss: 0.9050  Accuracy: 0.6750  Val_Accuracy: 0.7367
# Train Epoch: 7 [22320/50000 (45%)]  Loss: 0.5867  Accuracy: 0.7917  Val_Accuracy: 0.7117
# Train Epoch: 7 [23040/50000 (46%)]  Loss: 0.7558  Accuracy: 0.7167  Val_Accuracy: 0.7367
# Train Epoch: 7 [23760/50000 (48%)]  Loss: 0.9014  Accuracy: 0.6417  Val_Accuracy: 0.7133
# Train Epoch: 7 [24480/50000 (49%)]  Loss: 0.7650  Accuracy: 0.7333  Val_Accuracy: 0.7183
# Train Epoch: 7 [25200/50000 (50%)]  Loss: 0.8465  Accuracy: 0.7333  Val_Accuracy: 0.7083
# Train Epoch: 7 [25920/50000 (52%)]  Loss: 0.8161  Accuracy: 0.7250  Val_Accuracy: 0.6883
# Train Epoch: 7 [26640/50000 (53%)]  Loss: 0.7137  Accuracy: 0.7667  Val_Accuracy: 0.7100
# Train Epoch: 7 [27360/50000 (55%)]  Loss: 0.8479  Accuracy: 0.6750  Val_Accuracy: 0.7183
# Train Epoch: 7 [28080/50000 (56%)]  Loss: 0.6760  Accuracy: 0.7667  Val_Accuracy: 0.6600
# Train Epoch: 7 [28800/50000 (58%)]  Loss: 0.7340  Accuracy: 0.7583  Val_Accuracy: 0.7300
# Train Epoch: 7 [29520/50000 (59%)]  Loss: 0.6569  Accuracy: 0.7667  Val_Accuracy: 0.7333
# Train Epoch: 7 [30240/50000 (60%)]  Loss: 0.6409  Accuracy: 0.7917  Val_Accuracy: 0.7250
# Train Epoch: 7 [30960/50000 (62%)]  Loss: 0.8291  Accuracy: 0.7333  Val_Accuracy: 0.7000
# Train Epoch: 7 [31680/50000 (63%)]  Loss: 0.8644  Accuracy: 0.6917  Val_Accuracy: 0.7533
# Train Epoch: 7 [32400/50000 (65%)]  Loss: 0.6942  Accuracy: 0.7167  Val_Accuracy: 0.7117
# Train Epoch: 7 [33120/50000 (66%)]  Loss: 0.7885  Accuracy: 0.6917  Val_Accuracy: 0.7217
# Train Epoch: 7 [33840/50000 (68%)]  Loss: 0.8438  Accuracy: 0.7083  Val_Accuracy: 0.7283
# Train Epoch: 7 [34560/50000 (69%)]  Loss: 0.7278  Accuracy: 0.7250  Val_Accuracy: 0.6983
# Train Epoch: 7 [35280/50000 (71%)]  Loss: 0.7997  Accuracy: 0.7083  Val_Accuracy: 0.6783
# Train Epoch: 7 [36000/50000 (72%)]  Loss: 0.8732  Accuracy: 0.7333  Val_Accuracy: 0.7417
# Train Epoch: 7 [36720/50000 (73%)]  Loss: 0.8548  Accuracy: 0.6667  Val_Accuracy: 0.6733
# Train Epoch: 7 [37440/50000 (75%)]  Loss: 0.7445  Accuracy: 0.7000  Val_Accuracy: 0.6983
# Train Epoch: 7 [38160/50000 (76%)]  Loss: 0.6761  Accuracy: 0.7917  Val_Accuracy: 0.6583
# Train Epoch: 7 [38880/50000 (78%)]  Loss: 0.8575  Accuracy: 0.6917  Val_Accuracy: 0.6867
# Train Epoch: 7 [39600/50000 (79%)]  Loss: 0.5963  Accuracy: 0.8167  Val_Accuracy: 0.7017
# Train Epoch: 7 [40320/50000 (81%)]  Loss: 0.7488  Accuracy: 0.7750  Val_Accuracy: 0.7233
# Train Epoch: 7 [41040/50000 (82%)]  Loss: 0.7510  Accuracy: 0.7833  Val_Accuracy: 0.6783
# Train Epoch: 7 [41760/50000 (84%)]  Loss: 0.7716  Accuracy: 0.6917  Val_Accuracy: 0.7267
# Train Epoch: 7 [42480/50000 (85%)]  Loss: 0.7607  Accuracy: 0.7583  Val_Accuracy: 0.6883
# Train Epoch: 7 [43200/50000 (86%)]  Loss: 0.8180  Accuracy: 0.7250  Val_Accuracy: 0.7317
# Train Epoch: 7 [43920/50000 (88%)]  Loss: 0.8337  Accuracy: 0.7250  Val_Accuracy: 0.7350
# Train Epoch: 7 [44640/50000 (89%)]  Loss: 0.7775  Accuracy: 0.7333  Val_Accuracy: 0.7167
# Train Epoch: 7 [45360/50000 (91%)]  Loss: 0.8181  Accuracy: 0.7500  Val_Accuracy: 0.7150
# Train Epoch: 7 [46080/50000 (92%)]  Loss: 0.6860  Accuracy: 0.7500  Val_Accuracy: 0.7283
# Train Epoch: 7 [46800/50000 (94%)]  Loss: 0.6376  Accuracy: 0.8250  Val_Accuracy: 0.7167
# Train Epoch: 7 [47520/50000 (95%)]  Loss: 0.6397  Accuracy: 0.8083  Val_Accuracy: 0.7433
# Train Epoch: 7 [48240/50000 (96%)]  Loss: 0.9355  Accuracy: 0.6750  Val_Accuracy: 0.7333
# Train Epoch: 7 [48960/50000 (98%)]  Loss: 0.6674  Accuracy: 0.7500  Val_Accuracy: 0.7050
# Train Epoch: 7 [49680/50000 (99%)]  Loss: 0.6617  Accuracy: 0.8083  Val_Accuracy: 0.7050
# Train Epoch: 7 [50000/50000 (100%)]  Loss: 0.7814  Accuracy: 0.6875  Val_Accuracy: 0.7050
# Train  Accuracy: 0.7383  Loss: 0.7814
# Test  Accuracy: 0.7280  Loss: 26.0737
# Model Saved
# Time: 842.7979
#
# Train Epoch: 8 [0/50000 (0%)]
# Train Epoch: 8 [720/50000 (1%)]  Loss: 0.7613  Accuracy: 0.7333  Val_Accuracy: 0.6983
# Train Epoch: 8 [1440/50000 (3%)]  Loss: 0.6759  Accuracy: 0.7917  Val_Accuracy: 0.7233
# Train Epoch: 8 [2160/50000 (4%)]  Loss: 0.8416  Accuracy: 0.6667  Val_Accuracy: 0.7033
# Train Epoch: 8 [2880/50000 (6%)]  Loss: 0.7991  Accuracy: 0.7000  Val_Accuracy: 0.7350
# Train Epoch: 8 [3600/50000 (7%)]  Loss: 0.5403  Accuracy: 0.8250  Val_Accuracy: 0.7150
# Train Epoch: 8 [4320/50000 (9%)]  Loss: 0.7540  Accuracy: 0.7000  Val_Accuracy: 0.7233
# Train Epoch: 8 [5040/50000 (10%)]  Loss: 0.6478  Accuracy: 0.7583  Val_Accuracy: 0.7150
# Train Epoch: 8 [5760/50000 (12%)]  Loss: 0.6351  Accuracy: 0.8167  Val_Accuracy: 0.7067
# Train Epoch: 8 [6480/50000 (13%)]  Loss: 0.7496  Accuracy: 0.7417  Val_Accuracy: 0.7067
# Train Epoch: 8 [7200/50000 (14%)]  Loss: 0.6639  Accuracy: 0.8083  Val_Accuracy: 0.7317
# Train Epoch: 8 [7920/50000 (16%)]  Loss: 0.6392  Accuracy: 0.7833  Val_Accuracy: 0.7383
# Train Epoch: 8 [8640/50000 (17%)]  Loss: 0.7722  Accuracy: 0.6667  Val_Accuracy: 0.7250
# Train Epoch: 8 [9360/50000 (19%)]  Loss: 0.7409  Accuracy: 0.7000  Val_Accuracy: 0.7150
# Train Epoch: 8 [10080/50000 (20%)]  Loss: 0.5831  Accuracy: 0.8167  Val_Accuracy: 0.7467
# Train Epoch: 8 [10800/50000 (22%)]  Loss: 0.8290  Accuracy: 0.7250  Val_Accuracy: 0.7133
# Train Epoch: 8 [11520/50000 (23%)]  Loss: 0.6640  Accuracy: 0.7500  Val_Accuracy: 0.6783
# Train Epoch: 8 [12240/50000 (24%)]  Loss: 0.7519  Accuracy: 0.7417  Val_Accuracy: 0.7300
# Train Epoch: 8 [12960/50000 (26%)]  Loss: 0.8978  Accuracy: 0.7083  Val_Accuracy: 0.7317
# Train Epoch: 8 [13680/50000 (27%)]  Loss: 0.6468  Accuracy: 0.8083  Val_Accuracy: 0.7100
# Train Epoch: 8 [14400/50000 (29%)]  Loss: 1.0426  Accuracy: 0.6417  Val_Accuracy: 0.7600
# Train Epoch: 8 [15120/50000 (30%)]  Loss: 0.6756  Accuracy: 0.7750  Val_Accuracy: 0.7283
# Train Epoch: 8 [15840/50000 (32%)]  Loss: 0.6289  Accuracy: 0.7750  Val_Accuracy: 0.7250
# Train Epoch: 8 [16560/50000 (33%)]  Loss: 0.7258  Accuracy: 0.7083  Val_Accuracy: 0.6933
# Train Epoch: 8 [17280/50000 (35%)]  Loss: 0.9362  Accuracy: 0.6500  Val_Accuracy: 0.7300
# Train Epoch: 8 [18000/50000 (36%)]  Loss: 0.7533  Accuracy: 0.7333  Val_Accuracy: 0.6917
# Train Epoch: 8 [18720/50000 (37%)]  Loss: 0.5733  Accuracy: 0.8250  Val_Accuracy: 0.7217
# Train Epoch: 8 [19440/50000 (39%)]  Loss: 0.6200  Accuracy: 0.8000  Val_Accuracy: 0.6900
# Train Epoch: 8 [20160/50000 (40%)]  Loss: 0.7560  Accuracy: 0.7583  Val_Accuracy: 0.6783
# Train Epoch: 8 [20880/50000 (42%)]  Loss: 0.6889  Accuracy: 0.7333  Val_Accuracy: 0.7317
# Train Epoch: 8 [21600/50000 (43%)]  Loss: 0.7032  Accuracy: 0.7250  Val_Accuracy: 0.7600
# Train Epoch: 8 [22320/50000 (45%)]  Loss: 0.6045  Accuracy: 0.7833  Val_Accuracy: 0.7767
# Train Epoch: 8 [23040/50000 (46%)]  Loss: 0.7060  Accuracy: 0.7833  Val_Accuracy: 0.6833
# Train Epoch: 8 [23760/50000 (48%)]  Loss: 0.8770  Accuracy: 0.7083  Val_Accuracy: 0.7183
# Train Epoch: 8 [24480/50000 (49%)]  Loss: 0.6930  Accuracy: 0.7833  Val_Accuracy: 0.7300
# Train Epoch: 8 [25200/50000 (50%)]  Loss: 0.5917  Accuracy: 0.8000  Val_Accuracy: 0.7150
# Train Epoch: 8 [25920/50000 (52%)]  Loss: 0.6629  Accuracy: 0.7917  Val_Accuracy: 0.7433
# Train Epoch: 8 [26640/50000 (53%)]  Loss: 0.6634  Accuracy: 0.7667  Val_Accuracy: 0.6967
# ...
# Train Epoch: 10 [13680/50000 (27%)]  Loss: 0.5020  Accuracy: 0.8333  Val_Accuracy: 0.7167
# Train Epoch: 10 [14400/50000 (29%)]  Loss: 0.6585  Accuracy: 0.8000  Val_Accuracy: 0.7950
# Train Epoch: 10 [15120/50000 (30%)]  Loss: 0.6931  Accuracy: 0.7417  Val_Accuracy: 0.7467
# Train Epoch: 10 [15840/50000 (32%)]  Loss: 0.6914  Accuracy: 0.7833  Val_Accuracy: 0.7467
# Train Epoch: 10 [16560/50000 (33%)]  Loss: 0.7214  Accuracy: 0.7250  Val_Accuracy: 0.7283
# Train Epoch: 10 [17280/50000 (35%)]  Loss: 0.6515  Accuracy: 0.7750  Val_Accuracy: 0.7833
# Train Epoch: 10 [18000/50000 (36%)]  Loss: 0.5525  Accuracy: 0.8333  Val_Accuracy: 0.7617
# Train Epoch: 10 [18720/50000 (37%)]  Loss: 0.7630  Accuracy: 0.7167  Val_Accuracy: 0.7683
# Train Epoch: 10 [19440/50000 (39%)]  Loss: 0.6455  Accuracy: 0.7917  Val_Accuracy: 0.7717
# Train Epoch: 10 [20160/50000 (40%)]  Loss: 0.6596  Accuracy: 0.7833  Val_Accuracy: 0.7267
# Train Epoch: 10 [20880/50000 (42%)]  Loss: 0.6429  Accuracy: 0.7417  Val_Accuracy: 0.7400
# Train Epoch: 10 [21600/50000 (43%)]  Loss: 0.6042  Accuracy: 0.7750  Val_Accuracy: 0.7383
# Train Epoch: 10 [22320/50000 (45%)]  Loss: 0.6872  Accuracy: 0.7750  Val_Accuracy: 0.7517
# Train Epoch: 10 [23040/50000 (46%)]  Loss: 0.6773  Accuracy: 0.7750  Val_Accuracy: 0.7600
# Train Epoch: 10 [23760/50000 (48%)]  Loss: 0.7501  Accuracy: 0.6667  Val_Accuracy: 0.7500
# Train Epoch: 10 [24480/50000 (49%)]  Loss: 0.6313  Accuracy: 0.7750  Val_Accuracy: 0.7667
# Train Epoch: 10 [25200/50000 (50%)]  Loss: 0.4975  Accuracy: 0.8500  Val_Accuracy: 0.7583
# Train Epoch: 10 [25920/50000 (52%)]  Loss: 0.5730  Accuracy: 0.8000  Val_Accuracy: 0.7617
# Train Epoch: 10 [26640/50000 (53%)]  Loss: 0.6967  Accuracy: 0.7583  Val_Accuracy: 0.7500
# Train Epoch: 10 [27360/50000 (55%)]  Loss: 0.6922  Accuracy: 0.7833  Val_Accuracy: 0.7650
# Train Epoch: 10 [28080/50000 (56%)]  Loss: 0.6375  Accuracy: 0.7750  Val_Accuracy: 0.7367
# Train Epoch: 10 [28800/50000 (58%)]  Loss: 0.7310  Accuracy: 0.7500  Val_Accuracy: 0.7300
# Train Epoch: 10 [29520/50000 (59%)]  Loss: 0.6277  Accuracy: 0.7583  Val_Accuracy: 0.7417
# Train Epoch: 10 [30240/50000 (60%)]  Loss: 0.6073  Accuracy: 0.7750  Val_Accuracy: 0.7583
# Train Epoch: 10 [30960/50000 (62%)]  Loss: 0.6262  Accuracy: 0.7583  Val_Accuracy: 0.7150
# Train Epoch: 10 [31680/50000 (63%)]  Loss: 0.6448  Accuracy: 0.7917  Val_Accuracy: 0.7517
# Train Epoch: 10 [32400/50000 (65%)]  Loss: 0.5491  Accuracy: 0.7917  Val_Accuracy: 0.7417
# Train Epoch: 10 [33120/50000 (66%)]  Loss: 0.6369  Accuracy: 0.7917  Val_Accuracy: 0.7583
# Train Epoch: 10 [33840/50000 (68%)]  Loss: 0.7448  Accuracy: 0.6917  Val_Accuracy: 0.7617
# Train Epoch: 10 [34560/50000 (69%)]  Loss: 0.5751  Accuracy: 0.8167  Val_Accuracy: 0.7817
# Train Epoch: 10 [35280/50000 (71%)]  Loss: 0.6993  Accuracy: 0.7750  Val_Accuracy: 0.7750
# Train Epoch: 10 [36000/50000 (72%)]  Loss: 0.5703  Accuracy: 0.8000  Val_Accuracy: 0.7617
# Train Epoch: 10 [36720/50000 (73%)]  Loss: 0.6693  Accuracy: 0.7667  Val_Accuracy: 0.7883
# Train Epoch: 10 [37440/50000 (75%)]  Loss: 0.6954  Accuracy: 0.7167  Val_Accuracy: 0.7667
# Train Epoch: 10 [38160/50000 (76%)]  Loss: 0.5089  Accuracy: 0.8167  Val_Accuracy: 0.7483
# Train Epoch: 10 [38880/50000 (78%)]  Loss: 0.6901  Accuracy: 0.8083  Val_Accuracy: 0.7833
# Train Epoch: 10 [39600/50000 (79%)]  Loss: 0.6198  Accuracy: 0.7417  Val_Accuracy: 0.7333
# Train Epoch: 10 [40320/50000 (81%)]  Loss: 0.8038  Accuracy: 0.7417  Val_Accuracy: 0.7333
# Train Epoch: 10 [41040/50000 (82%)]  Loss: 0.7111  Accuracy: 0.7667  Val_Accuracy: 0.7733
# Train Epoch: 10 [41760/50000 (84%)]  Loss: 0.5124  Accuracy: 0.8500  Val_Accuracy: 0.7483
# Train Epoch: 10 [42480/50000 (85%)]  Loss: 0.6340  Accuracy: 0.7333  Val_Accuracy: 0.7467
# Train Epoch: 10 [43200/50000 (86%)]  Loss: 0.6447  Accuracy: 0.7833  Val_Accuracy: 0.7750
# Train Epoch: 10 [43920/50000 (88%)]  Loss: 0.5952  Accuracy: 0.8083  Val_Accuracy: 0.7200
# Train Epoch: 10 [44640/50000 (89%)]  Loss: 0.5134  Accuracy: 0.8500  Val_Accuracy: 0.7583
# Train Epoch: 10 [45360/50000 (91%)]  Loss: 0.5293  Accuracy: 0.8250  Val_Accuracy: 0.7417
# Train Epoch: 10 [46080/50000 (92%)]  Loss: 0.6357  Accuracy: 0.7583  Val_Accuracy: 0.7483
# Train Epoch: 10 [46800/50000 (94%)]  Loss: 0.8028  Accuracy: 0.7333  Val_Accuracy: 0.7500
# Train Epoch: 10 [47520/50000 (95%)]  Loss: 0.5686  Accuracy: 0.8083  Val_Accuracy: 0.7700
# Train Epoch: 10 [48240/50000 (96%)]  Loss: 0.4981  Accuracy: 0.8333  Val_Accuracy: 0.7500
# Train Epoch: 10 [48960/50000 (98%)]  Loss: 0.5427  Accuracy: 0.8083  Val_Accuracy: 0.7717
# Train Epoch: 10 [49680/50000 (99%)]  Loss: 0.6103  Accuracy: 0.7667  Val_Accuracy: 0.7650
# Train Epoch: 10 [50000/50000 (100%)]  Loss: 0.8293  Accuracy: 0.7625  Val_Accuracy: 0.7650
# Train  Accuracy: 0.7804  Loss: 0.8293
# Test  Accuracy: 0.7786  Loss: 22.0102
# Model Saved
# Time: 1029.6150
#
# Train Epoch: 11 [0/50000 (0%)]
# Train Epoch: 11 [720/50000 (1%)]  Loss: 0.5580  Accuracy: 0.7833  Val_Accuracy: 0.7567
# Train Epoch: 11 [1440/50000 (3%)]  Loss: 0.5680  Accuracy: 0.7833  Val_Accuracy: 0.7817
# Train Epoch: 11 [2160/50000 (4%)]  Loss: 0.6612  Accuracy: 0.7833  Val_Accuracy: 0.7450
# Train Epoch: 11 [2880/50000 (6%)]  Loss: 0.6912  Accuracy: 0.7500  Val_Accuracy: 0.7667
# Train Epoch: 11 [3600/50000 (7%)]  Loss: 0.5694  Accuracy: 0.7917  Val_Accuracy: 0.7517
# Train Epoch: 11 [4320/50000 (9%)]  Loss: 0.6817  Accuracy: 0.7333  Val_Accuracy: 0.7400
# Train Epoch: 11 [5040/50000 (10%)]  Loss: 0.7838  Accuracy: 0.7667  Val_Accuracy: 0.7367
# Train Epoch: 11 [5760/50000 (12%)]  Loss: 0.5347  Accuracy: 0.8333  Val_Accuracy: 0.7283
# Train Epoch: 11 [6480/50000 (13%)]  Loss: 0.3722  Accuracy: 0.8750  Val_Accuracy: 0.7633
# Train Epoch: 11 [7200/50000 (14%)]  Loss: 0.6787  Accuracy: 0.7250  Val_Accuracy: 0.7883
# Train Epoch: 11 [7920/50000 (16%)]  Loss: 0.5807  Accuracy: 0.8000  Val_Accuracy: 0.7800
# Train Epoch: 11 [8640/50000 (17%)]  Loss: 0.5313  Accuracy: 0.8417  Val_Accuracy: 0.7867
# Train Epoch: 11 [9360/50000 (19%)]  Loss: 0.6816  Accuracy: 0.7500  Val_Accuracy: 0.7717
# Train Epoch: 11 [10080/50000 (20%)]  Loss: 0.7378  Accuracy: 0.7750  Val_Accuracy: 0.7500
# Train Epoch: 11 [10800/50000 (22%)]  Loss: 0.6358  Accuracy: 0.7750  Val_Accuracy: 0.7500
# Train Epoch: 11 [11520/50000 (23%)]  Loss: 0.5881  Accuracy: 0.8250  Val_Accuracy: 0.7550
# Train Epoch: 11 [12240/50000 (24%)]  Loss: 0.5823  Accuracy: 0.7667  Val_Accuracy: 0.7883
# Train Epoch: 11 [12960/50000 (26%)]  Loss: 0.4976  Accuracy: 0.8333  Val_Accuracy: 0.7667
# Train Epoch: 11 [13680/50000 (27%)]  Loss: 0.6599  Accuracy: 0.7833  Val_Accuracy: 0.7883
# Train Epoch: 11 [14400/50000 (29%)]  Loss: 0.6246  Accuracy: 0.7750  Val_Accuracy: 0.7933
# Train Epoch: 11 [15120/50000 (30%)]  Loss: 0.5193  Accuracy: 0.7917  Val_Accuracy: 0.7367
# Train Epoch: 11 [15840/50000 (32%)]  Loss: 0.7067  Accuracy: 0.7500  Val_Accuracy: 0.7450
# Train Epoch: 11 [16560/50000 (33%)]  Loss: 0.5600  Accuracy: 0.8250  Val_Accuracy: 0.7533
# Train Epoch: 11 [17280/50000 (35%)]  Loss: 0.6942  Accuracy: 0.7417  Val_Accuracy: 0.7433
# Train Epoch: 11 [18000/50000 (36%)]  Loss: 0.6944  Accuracy: 0.7750  Val_Accuracy: 0.7117
# Train Epoch: 11 [18720/50000 (37%)]  Loss: 0.6885  Accuracy: 0.7917  Val_Accuracy: 0.7117
# Train Epoch: 11 [19440/50000 (39%)]  Loss: 0.5166  Accuracy: 0.8083  Val_Accuracy: 0.7617
# Train Epoch: 11 [20160/50000 (40%)]  Loss: 0.5019  Accuracy: 0.8083  Val_Accuracy: 0.7800
# Train Epoch: 11 [20880/50000 (42%)]  Loss: 0.5119  Accuracy: 0.8500  Val_Accuracy: 0.7217
# Train Epoch: 11 [21600/50000 (43%)]  Loss: 0.5489  Accuracy: 0.8333  Val_Accuracy: 0.7567
# Train Epoch: 11 [22320/50000 (45%)]  Loss: 0.6826  Accuracy: 0.7250  Val_Accuracy: 0.7183
# Train Epoch: 11 [23040/50000 (46%)]  Loss: 0.5597  Accuracy: 0.8167  Val_Accuracy: 0.7800
# Train Epoch: 11 [23760/50000 (48%)]  Loss: 0.6596  Accuracy: 0.7917  Val_Accuracy: 0.7517
# Train Epoch: 11 [24480/50000 (49%)]  Loss: 0.6010  Accuracy: 0.7750  Val_Accuracy: 0.7283
# Train Epoch: 11 [25200/50000 (50%)]  Loss: 0.6258  Accuracy: 0.7917  Val_Accuracy: 0.7350
# Train Epoch: 11 [25920/50000 (52%)]  Loss: 0.5910  Accuracy: 0.8167  Val_Accuracy: 0.7867
# Train Epoch: 11 [26640/50000 (53%)]  Loss: 0.5833  Accuracy: 0.8083  Val_Accuracy: 0.7667
# Train Epoch: 11 [27360/50000 (55%)]  Loss: 0.5143  Accuracy: 0.8083  Val_Accuracy: 0.7450
# Train Epoch: 11 [28080/50000 (56%)]  Loss: 0.4890  Accuracy: 0.8333  Val_Accuracy: 0.7533
# Train Epoch: 11 [28800/50000 (58%)]  Loss: 0.5464  Accuracy: 0.8000  Val_Accuracy: 0.7567
# Train Epoch: 11 [29520/50000 (59%)]  Loss: 0.6854  Accuracy: 0.7333  Val_Accuracy: 0.7717
# Train Epoch: 11 [30240/50000 (60%)]  Loss: 0.5104  Accuracy: 0.8417  Val_Accuracy: 0.7317
# Train Epoch: 11 [30960/50000 (62%)]  Loss: 0.4773  Accuracy: 0.8250  Val_Accuracy: 0.7683
# Train Epoch: 11 [31680/50000 (63%)]  Loss: 0.5299  Accuracy: 0.8667  Val_Accuracy: 0.7783
# Train Epoch: 11 [32400/50000 (65%)]  Loss: 0.7164  Accuracy: 0.7667  Val_Accuracy: 0.7650
# Train Epoch: 11 [33120/50000 (66%)]  Loss: 0.5551  Accuracy: 0.7917  Val_Accuracy: 0.7417
# Train Epoch: 11 [33840/50000 (68%)]  Loss: 0.7567  Accuracy: 0.7250  Val_Accuracy: 0.7733
# Train Epoch: 11 [34560/50000 (69%)]  Loss: 0.5385  Accuracy: 0.8000  Val_Accuracy: 0.7117
# Train Epoch: 11 [35280/50000 (71%)]  Loss: 0.6559  Accuracy: 0.7833  Val_Accuracy: 0.7767
# Train Epoch: 11 [36000/50000 (72%)]  Loss: 0.5574  Accuracy: 0.7833  Val_Accuracy: 0.7300
# Train Epoch: 11 [36720/50000 (73%)]  Loss: 0.4846  Accuracy: 0.8417  Val_Accuracy: 0.7900
# Train Epoch: 11 [37440/50000 (75%)]  Loss: 0.5782  Accuracy: 0.7833  Val_Accuracy: 0.7650
# Train Epoch: 11 [38160/50000 (76%)]  Loss: 0.7319  Accuracy: 0.7583  Val_Accuracy: 0.7850
# Train Epoch: 11 [38880/50000 (78%)]  Loss: 0.5953  Accuracy: 0.7833  Val_Accuracy: 0.7667
# Train Epoch: 11 [39600/50000 (79%)]  Loss: 0.4373  Accuracy: 0.8583  Val_Accuracy: 0.7567
# Train Epoch: 11 [40320/50000 (81%)]  Loss: 0.6132  Accuracy: 0.7750  Val_Accuracy: 0.7550
# Train Epoch: 11 [41040/50000 (82%)]  Loss: 0.7400  Accuracy: 0.7083  Val_Accuracy: 0.7467
# Train Epoch: 11 [41760/50000 (84%)]  Loss: 0.7500  Accuracy: 0.7583  Val_Accuracy: 0.7917
# Train Epoch: 11 [42480/50000 (85%)]  Loss: 0.5481  Accuracy: 0.8250  Val_Accuracy: 0.7300
# Train Epoch: 11 [43200/50000 (86%)]  Loss: 0.6961  Accuracy: 0.7667  Val_Accuracy: 0.7283
# Train Epoch: 11 [43920/50000 (88%)]  Loss: 0.5662  Accuracy: 0.7500  Val_Accuracy: 0.7700
# Train Epoch: 11 [44640/50000 (89%)]  Loss: 0.4111  Accuracy: 0.8667  Val_Accuracy: 0.7933
# Train Epoch: 11 [45360/50000 (91%)]  Loss: 0.4523  Accuracy: 0.8417  Val_Accuracy: 0.7833
# Train Epoch: 11 [46080/50000 (92%)]  Loss: 0.5650  Accuracy: 0.7750  Val_Accuracy: 0.7517
# Train Epoch: 11 [46800/50000 (94%)]  Loss: 0.5492  Accuracy: 0.8333  Val_Accuracy: 0.7450
# Train Epoch: 11 [47520/50000 (95%)]  Loss: 0.5423  Accuracy: 0.8417  Val_Accuracy: 0.7800
# Train Epoch: 11 [48240/50000 (96%)]  Loss: 0.5697  Accuracy: 0.8083  Val_Accuracy: 0.7783
# Train Epoch: 11 [48960/50000 (98%)]  Loss: 0.5656  Accuracy: 0.8250  Val_Accuracy: 0.7733
# Train Epoch: 11 [49680/50000 (99%)]  Loss: 0.7134  Accuracy: 0.7250  Val_Accuracy: 0.7500
# Train Epoch: 11 [50000/50000 (100%)]  Loss: 0.4622  Accuracy: 0.8375  Val_Accuracy: 0.7500
# Train  Accuracy: 0.7882  Loss: 0.4622
# Test  Accuracy: 0.7550  Loss: 23.5626
# Time: 942.2519
#
# Train Epoch: 12 [0/50000 (0%)]
# Train Epoch: 12 [720/50000 (1%)]  Loss: 0.7081  Accuracy: 0.7500  Val_Accuracy: 0.7667
# Train Epoch: 12 [1440/50000 (3%)]  Loss: 0.6207  Accuracy: 0.8167  Val_Accuracy: 0.7733
# Train Epoch: 12 [2160/50000 (4%)]  Loss: 0.5870  Accuracy: 0.7750  Val_Accuracy: 0.7417
# Train Epoch: 12 [2880/50000 (6%)]  Loss: 0.5668  Accuracy: 0.8083  Val_Accuracy: 0.7883
# Train Epoch: 12 [3600/50000 (7%)]  Loss: 0.5682  Accuracy: 0.8250  Val_Accuracy: 0.7683
# Train Epoch: 12 [4320/50000 (9%)]  Loss: 0.7054  Accuracy: 0.7167  Val_Accuracy: 0.7167
# Train Epoch: 12 [5040/50000 (10%)]  Loss: 0.4451  Accuracy: 0.8500  Val_Accuracy: 0.7333
# Train Epoch: 12 [5760/50000 (12%)]  Loss: 0.5588  Accuracy: 0.8000  Val_Accuracy: 0.7500
# Train Epoch: 12 [6480/50000 (13%)]  Loss: 0.7270  Accuracy: 0.7750  Val_Accuracy: 0.7683
# Train Epoch: 12 [7200/50000 (14%)]  Loss: 0.6021  Accuracy: 0.8250  Val_Accuracy: 0.7883
# Train Epoch: 12 [7920/50000 (16%)]  Loss: 0.4946  Accuracy: 0.8333  Val_Accuracy: 0.7600
# Train Epoch: 12 [8640/50000 (17%)]  Loss: 0.5677  Accuracy: 0.7417  Val_Accuracy: 0.7683
# Train Epoch: 12 [9360/50000 (19%)]  Loss: 0.5822  Accuracy: 0.7917  Val_Accuracy: 0.7950
# Train Epoch: 12 [10080/50000 (20%)]  Loss: 0.5185  Accuracy: 0.8083  Val_Accuracy: 0.7567
# Train Epoch: 12 [10800/50000 (22%)]  Loss: 0.7121  Accuracy: 0.7250  Val_Accuracy: 0.7950
# Train Epoch: 12 [11520/50000 (23%)]  Loss: 0.5571  Accuracy: 0.8083  Val_Accuracy: 0.7383
# Train Epoch: 12 [12240/50000 (24%)]  Loss: 0.5352  Accuracy: 0.8417  Val_Accuracy: 0.7750
# Train Epoch: 12 [12960/50000 (26%)]  Loss: 0.6421  Accuracy: 0.8333  Val_Accuracy: 0.7300
# Train Epoch: 12 [13680/50000 (27%)]  Loss: 0.5573  Accuracy: 0.7917  Val_Accuracy: 0.7417
# Train Epoch: 12 [14400/50000 (29%)]  Loss: 0.5942  Accuracy: 0.7833  Val_Accuracy: 0.7500
# Train Epoch: 12 [15120/50000 (30%)]  Loss: 0.5614  Accuracy: 0.7833  Val_Accuracy: 0.8033
# Train Epoch: 12 [15840/50000 (32%)]  Loss: 0.6305  Accuracy: 0.7583  Val_Accuracy: 0.7633
# Train Epoch: 12 [16560/50000 (33%)]  Loss: 0.8637  Accuracy: 0.7250  Val_Accuracy: 0.7783
# Train Epoch: 12 [17280/50000 (35%)]  Loss: 0.5731  Accuracy: 0.8083  Val_Accuracy: 0.7817
# Train Epoch: 12 [18000/50000 (36%)]  Loss: 0.6119  Accuracy: 0.7750  Val_Accuracy: 0.7500
# Train Epoch: 12 [18720/50000 (37%)]  Loss: 0.5745  Accuracy: 0.8083  Val_Accuracy: 0.7867
# Train Epoch: 12 [19440/50000 (39%)]  Loss: 0.7245  Accuracy: 0.7250  Val_Accuracy: 0.7633
# Train Epoch: 12 [20160/50000 (40%)]  Loss: 0.6915  Accuracy: 0.8250  Val_Accuracy: 0.7717
# Train Epoch: 12 [20880/50000 (42%)]  Loss: 0.7766  Accuracy: 0.7167  Val_Accuracy: 0.7433
# Train Epoch: 12 [21600/50000 (43%)]  Loss: 0.5970  Accuracy: 0.8000  Val_Accuracy: 0.7350
# Train Epoch: 12 [22320/50000 (45%)]  Loss: 0.7387  Accuracy: 0.7083  Val_Accuracy: 0.7600
# Train Epoch: 12 [23040/50000 (46%)]  Loss: 0.6699  Accuracy: 0.7917  Val_Accuracy: 0.7800
# Train Epoch: 12 [23760/50000 (48%)]  Loss: 0.5212  Accuracy: 0.8083  Val_Accuracy: 0.7667
# Train Epoch: 12 [24480/50000 (49%)]  Loss: 0.4040  Accuracy: 0.8583  Val_Accuracy: 0.7700
# Train Epoch: 12 [25200/50000 (50%)]  Loss: 0.4728  Accuracy: 0.8583  Val_Accuracy: 0.7417
# Train Epoch: 12 [25920/50000 (52%)]  Loss: 0.4967  Accuracy: 0.8333  Val_Accuracy: 0.7517
# Train Epoch: 12 [26640/50000 (53%)]  Loss: 0.5561  Accuracy: 0.8083  Val_Accuracy: 0.7850
# Train Epoch: 12 [27360/50000 (55%)]  Loss: 0.5907  Accuracy: 0.7333  Val_Accuracy: 0.7550
# Train Epoch: 12 [28080/50000 (56%)]  Loss: 0.5147  Accuracy: 0.8083  Val_Accuracy: 0.7683
# Train Epoch: 12 [28800/50000 (58%)]  Loss: 0.5552  Accuracy: 0.8083  Val_Accuracy: 0.7433
# Train Epoch: 12 [29520/50000 (59%)]  Loss: 0.6167  Accuracy: 0.7750  Val_Accuracy: 0.7700
# Train Epoch: 12 [30240/50000 (60%)]  Loss: 0.5467  Accuracy: 0.7750  Val_Accuracy: 0.7567
# Train Epoch: 12 [30960/50000 (62%)]  Loss: 0.7184  Accuracy: 0.7583  Val_Accuracy: 0.7617
# Train Epoch: 12 [31680/50000 (63%)]  Loss: 0.7126  Accuracy: 0.7667  Val_Accuracy: 0.7383
# Train Epoch: 12 [32400/50000 (65%)]  Loss: 0.5968  Accuracy: 0.8167  Val_Accuracy: 0.7583
# Train Epoch: 12 [33120/50000 (66%)]  Loss: 0.6224  Accuracy: 0.8167  Val_Accuracy: 0.7900
# Train Epoch: 12 [33840/50000 (68%)]  Loss: 0.6063  Accuracy: 0.7750  Val_Accuracy: 0.7600
# Train Epoch: 12 [34560/50000 (69%)]  Loss: 0.5511  Accuracy: 0.7833  Val_Accuracy: 0.7517
# Train Epoch: 12 [35280/50000 (71%)]  Loss: 0.5823  Accuracy: 0.8083  Val_Accuracy: 0.7533
# Train Epoch: 12 [36000/50000 (72%)]  Loss: 0.5960  Accuracy: 0.8167  Val_Accuracy: 0.7650
# Train Epoch: 12 [36720/50000 (73%)]  Loss: 0.6252  Accuracy: 0.7833  Val_Accuracy: 0.7833
# Train Epoch: 12 [37440/50000 (75%)]  Loss: 0.6164  Accuracy: 0.7500  Val_Accuracy: 0.7983
# Train Epoch: 12 [38160/50000 (76%)]  Loss: 0.6065  Accuracy: 0.7667  Val_Accuracy: 0.7650

# %% [markdown]
# # Plot Training Record

# %%
bufferSize = 10

trainCounterArr = []
for i in range(len(trainLossArr)-bufferSize):
    trainCounterArr.append(i)

trainLossArr_ = []
valLossArr_ = []

for i in range(len(trainLossArr)-bufferSize):
    trainLossArr_.append(np.average(trainLossArr[i:i+bufferSize]))
    valLossArr_.append(np.average(valLossArr[i:i+bufferSize]))

fig = plt.figure()
plt.plot(trainCounterArr, trainLossArr_, color='blue')
plt.plot(trainCounterArr, valLossArr_, color='red')
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.xlabel('number of training examples seen')
plt.ylabel('negative log likelihood loss')

# %% [markdown]
# # Load Saved Weights

# %%
network.load_state_dict(torch.load("C:\\Users\\jason\\OneDrive\\文件\\Python NN\\Pytorch CIFAR-10\\weight191120.pth"))

# %% [markdown]
# # Final Test

# %%
testData = datasets.ImageFolder(testDir,transform = testAugumentation)
testLoader = torch.utils.data.DataLoader(testData,batch_size = 50,shuffle = False)

loss,acc = test()

# %% [markdown]
# # Load Result

# %%
testDataSize = 10000
testSize = 50

output_epoch = np.zeros([testDataSize,outSize])
ans = np.zeros([testDataSize])
out = np.zeros([testDataSize,2])

for i, (x, y) in enumerate(testLoader):
    x = x.cuda()
    output_epoch[i*testSize:(i+1)*testSize,:] = network(x).cpu().detach().numpy()
    ans[i*testSize:(i+1)*testSize] = y.cpu()
    
    output_batch = F.softmax(network(x), dim=1)
    for j in range(np.shape(output_batch)[0]):
        out[i*testSize+j,0] = output_batch[j].argmax()
        out[i*testSize+j,1] = output_batch[j].max().detach().cpu().numpy()

print(out)
# out: [label,prop]

# %% [markdown]
# # Find Best 5 and Worst 5

# %%
class_max = np.zeros([outSize,10])
# class_max: [1st pos_dataset,...,5th pos_dataset , 1st val,...,5th val]

for i in range(testDataSize):
    idx = out[i,0]
    val = out[i,1]
    if val > class_max[int(idx),5]:
        class_max[int(idx),6:9] = class_max[int(idx),5:8]
        class_max[int(idx),5] = val
        class_max[int(idx),1:4] = class_max[int(idx),0:3]
        class_max[int(idx),0] = i
    elif val > class_max[int(idx),6]:
        class_max[int(idx),7:9] = class_max[int(idx),6:8]
        class_max[int(idx),6] = val
        class_max[int(idx),2:4] = class_max[int(idx),1:3]
        class_max[int(idx),1] = i
    elif val > class_max[int(idx),7]:
        class_max[int(idx),8:9] = class_max[int(idx),7:8]
        class_max[int(idx),7] = val
        class_max[int(idx),3:4] = class_max[int(idx),2:3]
        class_max[int(idx),2] = i
    elif val > class_max[int(idx),8]:
        class_max[int(idx),9] = class_max[int(idx),8]
        class_max[int(idx),8] = val
        class_max[int(idx),4] = class_max[int(idx),3]
        class_max[int(idx),3] = i
    elif val > class_max[int(idx),9]:
        class_max[int(idx),9] = val
        class_max[int(idx),4] = i
        
class_min = np.zeros([outSize,10])+1000

for i in range(testDataSize):
    idx = out[i,0]
    val = out[i,1]
    if val < class_min[int(idx),5]:
        class_min[int(idx),6:9] = class_min[int(idx),5:8]
        class_min[int(idx),5] = val
        class_min[int(idx),1:4] = class_min[int(idx),0:3]
        class_min[int(idx),0] = i
    elif val < class_min[int(idx),6]:
        class_min[int(idx),7:9] = class_min[int(idx),6:8]
        class_min[int(idx),6] = val
        class_min[int(idx),2:4] = class_min[int(idx),1:3]
        class_min[int(idx),1] = i
    elif val < class_min[int(idx),7]:
        class_min[int(idx),8:9] = class_min[int(idx),7:8]
        class_min[int(idx),7] = val
        class_min[int(idx),3:4] = class_min[int(idx),2:3]
        class_min[int(idx),2] = i
    elif val < class_min[int(idx),8]:
        class_min[int(idx),9] = class_min[int(idx),8]
        class_min[int(idx),8] = val
        class_min[int(idx),4] = class_min[int(idx),3]
        class_min[int(idx),3] = i
    elif val < class_min[int(idx),9]:
        class_min[int(idx),9] = val
        class_min[int(idx),4] = i

# %%
print('MAX')
for i in range(outSize):
    for j in range(5):
        img = testData.__getitem__(int(class_max[i,j]))[0]
        img = np.transpose(img, (1, 2, 0))
        plt.subplot(1,5,j+1)
        plt.imshow(img)
        plt.title("Idx:{}".format(int(class_max[i,j])+11500))
    plt.show()

print('MIN')
for i in range(outSize):
    for j in range(5):
        img = testData.__getitem__(int(class_min[i,j]))[0]
        img = np.transpose(img, (1, 2, 0))
        plt.subplot(1,5,j+1)
        plt.imshow(img)
        plt.title("Idx:{}".format(int(class_min[i,j])+11500))
    plt.show()

# %%
ConfusionMatrix = np.zeros([outSize,outSize])

for i in range(testDataSize):
    ConfusionMatrix[int(ans[i]),int(out[i,0])] = ConfusionMatrix[int(ans[i]),int(out[i,0])]+1
    
print(ConfusionMatrix)

positive = np.zeros([outSize])
negative = np.zeros([outSize])

for i in range(outSize):
    positive[i] = ConfusionMatrix[i,i]/np.sum(ConfusionMatrix[:,i])
    negative[i] = (np.sum(ConfusionMatrix[:i,:i])+np.sum(ConfusionMatrix[(i+1):,:i])+np.sum(ConfusionMatrix[:i,(i+1):])+np.sum(ConfusionMatrix[(i+1):,(i+1):]))/(np.sum(ConfusionMatrix[:,:i])+np.sum(ConfusionMatrix[:,(i+1):]))

print("\n Airplane   Automobile Bird       Cat        Deer       Dog\n Frog       Horse      Ship       Truck")
print(positive)
print(negative)

# %%
print('Memory Usage:')
print('Allocated:', torch.cuda.memory_allocated(0)/1024/1204, 'MB')
print('Cached:   ', torch.cuda.memory_allocated(0)/1024/1024, 'MB')
